# %%
from riotwatcher import LolWatcher, ApiError
import pandas as pd
import numpy as np 
import sqlite3
from time import sleep
from apikey import API_KEY

# %%
watcher = LolWatcher(API_KEY)
region = 'na1'

# %%
connection = sqlite3.connect("riot_matches2.db")
create_match_table = """CREATE TABLE IF NOT EXISTS match (
id INTEGER PRIMARY KEY,
game_id TEXT,
blue_dragons INTEGER,
blue_heralds INTEGER,
blue_barons INTEGER,
blue_turrets INTEGER,
blue_kills INTEGER,
blue_gold_20 INTEGER,
red_dragons INTEGER,
red_heralds INTEGER,
red_barons INTEGER,
red_turrets INTEGER,
red_kills INTEGER,
red_gold_20 INTEGER,
winner TEXT
)"""
cur = connection.cursor()
cur.execute(create_match_table)
insert_match = "INSERT OR IGNORE INTO match (game_id, blue_dragons, blue_heralds, blue_barons, blue_turrets, blue_kills, blue_gold_20, red_dragons, red_heralds, red_barons, red_turrets, red_kills, red_gold_20, winner) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)"

# %%
challenger_dto = watcher.league.challenger_by_queue(region, "RANKED_SOLO_5x5")
challenger_players = challenger_dto["entries"]
challenger_players
# Out:
# [{'summonerId': 'OMLCH5F1BXzTWLQlyoCTbHAyXtYXVkpXbDfLRkapP44oXeE',
#   'summonerName': 'Ćocá',
#   'leaguePoints': 529,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'dBReJCk3uJfXRy9TJSuOOozlPMvEm78eSlffo5DgeL8KFLEl',
#   'summonerName': 'meiyouhuitoulu',
#   'leaguePoints': 505,
#   'rank': 'I',
#   'wins': 55,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'olLWYGB7rcdUlDH-mZfnesENXVbWLKsprpQajlYbE7lVjDaN',
#   'summonerName': 'TL Jensen',
#   'leaguePoints': 594,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'TIfYnYYdIM4GnKaFXHSHCmq9VlKL277teoDnSXil41tn_gI',
#   'summonerName': 'Detention',
#   'leaguePoints': 509,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '7IfngXZI0tMJhaHPXjNr_galf0cAPK_7J0Lpnl44s7QQF-s22rtCCwS1Yg',
#   'summonerName': 'Yura1',
#   'leaguePoints': 590,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'cMnZQQGT6E2rQXl0WuA6QODJmqzSKb0oMTZC3-mdCz3LzIk',
#   'summonerName': 'Keel7',
#   'leaguePoints': 853,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 73,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'RYs10CE79eS2B5rlE_9lz3DNok-nAkVNzGM3K5XJ53EBgNLC',
#   'summonerName': 'TFF MikeHct',
#   'leaguePoints': 573,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'kbfFNO4Rtrf13YQDq2l4TdXLonmEJeLvfdcBFMZeqRu0IRMa',
#   'summonerName': 'DAVEMON99',
#   'leaguePoints': 696,
#   'rank': 'I',
#   'wins': 101,
#   'losses': 92,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'u5c64MfzXcu15zjhuwjVhcjoMLTBd2AoMPsK44V6OPEbtqQ',
#   'summonerName': 'Ariendel',
#   'leaguePoints': 702,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 73,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '04A0Ufvr6Yg4bebJ4uUv41-0Mqa_APLdzZyhijuvoyqKt20',
#   'summonerName': 'nathan we miss u',
#   'leaguePoints': 503,
#   'rank': 'I',
#   'wins': 117,
#   'losses': 105,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'KvY92Iil1IsoxtZAR5DpSREUJt89wNGSOS64WR_lYZbBiSw',
#   'summonerName': 'Tojí Fushiguro',
#   'leaguePoints': 605,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '2xyTZR6YWBXsMatVD97TFkTTz8vCJEJQ9JuwR9HZsqxhbMQ',
#   'summonerName': 'The Tank Man',
#   'leaguePoints': 624,
#   'rank': 'I',
#   'wins': 71,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'T3XZS-GNoquJ7C-FfL1IyNyl1YdsdGexvMlSSLKQV6e_IqnKyu3QDRmMnw',
#   'summonerName': 'TFBlade2',
#   'leaguePoints': 765,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'GPcUAipB_-cToB41ys2mc6qbyCthsnhVOocJDC9uGzDsQJST',
#   'summonerName': 'JueJue ÒwÓ fan',
#   'leaguePoints': 503,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 39,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'dYeSdzEF_kry3vAw3Q6KFzpgUMEZGO21tgKK_stJ9D3TFwc',
#   'summonerName': 'Kim Down',
#   'leaguePoints': 600,
#   'rank': 'I',
#   'wins': 59,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'UdUWrprENRXrYNnNMATInip83blUeC6pDLSE78GH6a_yT-k',
#   'summonerName': 'Denathor',
#   'leaguePoints': 764,
#   'rank': 'I',
#   'wins': 123,
#   'losses': 106,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'YMMdLCbSR42-3ludDkxDiHobX3NitdlpXEICG0bL9fzDKaM',
#   'summonerName': 'Latence',
#   'leaguePoints': 525,
#   'rank': 'I',
#   'wins': 136,
#   'losses': 128,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ZBaBEjgUOBkeOE7Xn11zJkHo_EEe9uNI5VGDeIG46cVgA-s',
#   'summonerName': 'DC egc wananzoe',
#   'leaguePoints': 517,
#   'rank': 'I',
#   'wins': 99,
#   'losses': 90,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'T8dgNh6uyT5mE5kHhG8OH-Fo8eYNg5coWuEMXzVRmsfRxNw',
#   'summonerName': 'What a noob',
#   'leaguePoints': 571,
#   'rank': 'I',
#   'wins': 95,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '-zYeMIMtcJ3Xmlphp7i8mLx3ypahxDayJAtNi2XdX7il9hk',
#   'summonerName': 'align my chakras',
#   'leaguePoints': 536,
#   'rank': 'I',
#   'wins': 87,
#   'losses': 80,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'gKnyE2oLYHnVnZvAvEyHKKELR_0ceOUVFvPtaV6t9qf-GvI',
#   'summonerName': 'billyyyy',
#   'leaguePoints': 959,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'eHAJSi0TZKxc-fi4rmdxA54bWXRN8c9CFyNhwB8Cx-sChzo3',
#   'summonerName': 'Well play sir ',
#   'leaguePoints': 511,
#   'rank': 'I',
#   'wins': 112,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'hnB3rb_7aArFo3lOEWPvGif-l_Z0HQTLmSD4rMj3BM6Fsb1qo5S15kv1bA',
#   'summonerName': 'Shogo2',
#   'leaguePoints': 884,
#   'rank': 'I',
#   'wins': 93,
#   'losses': 76,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'c200g30dM4X0DjX1NQEDnnNBvGvT0uL_v8J4MoM6de0h61U',
#   'summonerName': 'rocks908',
#   'leaguePoints': 592,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '2ILfbun0llcUmPZtYM_CJ1GXC-3o5d-pfkLW3P2cRgor9S8',
#   'summonerName': 'DÑA',
#   'leaguePoints': 517,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'R-pKa5Oj0KHpbkGka3dNDUcKFhnLWqLJSaDiKJXZhhixbeFuccJkjB6JTA',
#   'summonerName': 'C9 Winsome FAN',
#   'leaguePoints': 633,
#   'rank': 'I',
#   'wins': 60,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'FZ-hOcROICnvto-T5rSuFNJHyxGvUGeeJVfS5sXhzip2Rxk',
#   'summonerName': 'KingClueless',
#   'leaguePoints': 614,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'MaWZNN-5GDf0v_1zgMQ05kvP6m6YuJjyBR7RkPpgMsKuEUoxF5jD-2eZ-w',
#   'summonerName': 'Old supp0rt',
#   'leaguePoints': 535,
#   'rank': 'I',
#   'wins': 68,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Vie9s8oWl42HcZbQ01n_Gxi1fnBB_kMHc4QBNA8A573Gixs',
#   'summonerName': 'nifty jg',
#   'leaguePoints': 525,
#   'rank': 'I',
#   'wins': 67,
#   'losses': 48,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '1KJb3NSproymrrWpTgB9Pqa09MhRZxNMFQkNEnjd6cto4EOu_hqpBdDfLg',
#   'summonerName': 'Naapes',
#   'leaguePoints': 509,
#   'rank': 'I',
#   'wins': 98,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'Wg542AgVxILHQTmiKqJHfe--x1PlEtM9QHAobQ3xUITXgSI',
#   'summonerName': 'Szochs',
#   'leaguePoints': 729,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 72,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'pYphlOrM4FJSyLjvz06GasxO87dpcceqG4lBLlAiGIVOI4hT',
#   'summonerName': 'DC EGC SOL',
#   'leaguePoints': 623,
#   'rank': 'I',
#   'wins': 102,
#   'losses': 78,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '-9kmwVihDe4POWZOUsWC1sWewyhI-Qr0E5Ie1oG0T72z1uQ',
#   'summonerName': 'AkenoHimejimaDxD',
#   'leaguePoints': 616,
#   'rank': 'I',
#   'wins': 115,
#   'losses': 93,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '1vPEpI7mekjNdGSTymD8AyAaylthHYHoIvHy0nV4eFnEDaw',
#   'summonerName': 'Doubtfull',
#   'leaguePoints': 505,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'gGCNrgmZtjH9a56qiCHB_B3kZkWQpeHwWMDUSAXGBSVbD_I',
#   'summonerName': 'RoseThorn',
#   'leaguePoints': 500,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 34,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Ezvu_371oSOf3smaHoN78Bd2ZHcsewwW61GWsDVTQ7MOb94',
#   'summonerName': 'vx koyiqaq',
#   'leaguePoints': 607,
#   'rank': 'I',
#   'wins': 67,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '9UOXITIMeMm1CVnVlZ5YszIAELVnRQquWu3JrFN0Fz25uH4',
#   'summonerName': 'Chookies',
#   'leaguePoints': 506,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'FyUEhCz6sk114dy3rUJN2ZM2PLSchivNQb4hqvkgkahCIfV4',
#   'summonerName': 'Dc EGC EKKO',
#   'leaguePoints': 510,
#   'rank': 'I',
#   'wins': 145,
#   'losses': 132,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'HazXaoxWdBOonZ5s0oxWHXjEl1kxH3j1ag-cMlXxfZEG37o',
#   'summonerName': 'Blacc Massu',
#   'leaguePoints': 508,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'QbK85w2XrsQpiE61u79IMFjAvGrB2ZZnmtoJU16EpDlRKe4',
#   'summonerName': 'The Lo',
#   'leaguePoints': 513,
#   'rank': 'I',
#   'wins': 98,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'B8BCpLe5D3wdb_6HmGcPLnj4Jz3fc83Ll9QI-zDfz0gahk0',
#   'summonerName': 'Annie Bot',
#   'leaguePoints': 517,
#   'rank': 'I',
#   'wins': 80,
#   'losses': 62,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'f-kNYYCrmbotad4bcHuDPm12mKnm7qvor4Tr0pbm9-j3AWM',
#   'summonerName': 'Cupic',
#   'leaguePoints': 1105,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 76,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'IIqtxuo-kkfw5ZBKhELno2HE1VdBWmqSiThZby4-O-LvtN0',
#   'summonerName': 'jamican banana',
#   'leaguePoints': 650,
#   'rank': 'I',
#   'wins': 118,
#   'losses': 106,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '53QiNoTfzyUSh1DSHC_rwyhd6lqXS7pJ8MzOjwGg0lO-SUi4NnkR5SHqBg',
#   'summonerName': 'FLY Twoballs',
#   'leaguePoints': 890,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '5SYalYeW0VAI26DUHw0Iixwl0k6PNn71fmUEz9d7bubQBxE',
#   'summonerName': 'C9 Copy',
#   'leaguePoints': 1220,
#   'rank': 'I',
#   'wins': 96,
#   'losses': 58,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'QJiqBfyalbM6Q9yTc6ZgEyiVO6qdPEBzbOh2xtw27m5HliQ',
#   'summonerName': 'Quantum',
#   'leaguePoints': 573,
#   'rank': 'I',
#   'wins': 61,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'jigH8aREFOAvgex9pysSS08_Gk0Kvqn6xKR-AtLEy9rk8UJy2q_xWMegIg',
#   'summonerName': 'Kufa',
#   'leaguePoints': 1039,
#   'rank': 'I',
#   'wins': 103,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'iG8jCzV7hwW-yyr5hFQAxy4DpTBByZ0VfTp0p-8PRzgVgYU',
#   'summonerName': 'C9 Zven',
#   'leaguePoints': 570,
#   'rank': 'I',
#   'wins': 67,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'XI7FBfugEF-jtOv-NZQ0zC1ybX6DP96yPaiiRzv6vKthmf4',
#   'summonerName': 'putmeonsagecoach',
#   'leaguePoints': 547,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 59,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '8DNLpiSFN9ldLBeJkF3D6HEI83gxcH9H5hr4m2ivQ48zyMM',
#   'summonerName': 'TwTv KoKooPuffs',
#   'leaguePoints': 757,
#   'rank': 'I',
#   'wins': 147,
#   'losses': 142,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '3v2s0xdC04hwxdV2aZ2M8aLbTp0UCNg_4pomfB7y4WRwbFI',
#   'summonerName': 'donb',
#   'leaguePoints': 577,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '0Yrb8NeQJatHNpcu0YaQYqfRE7fR7bhdG_tZMWnyfOSNOsgL',
#   'summonerName': 'RapÍd',
#   'leaguePoints': 502,
#   'rank': 'I',
#   'wins': 108,
#   'losses': 95,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'O-yBD3odK5rN0HIfDnsN_b28Wvi5ttfuSaCLA1KHW1zwL8Bi',
#   'summonerName': '100T Closerr',
#   'leaguePoints': 1061,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 36,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '7AQxs2-46PIf6k0zOJvbpQzy4TUFMnrc7lIAJ33C-5hvtGbXvqDtVyynNA',
#   'summonerName': 'ryooooma22',
#   'leaguePoints': 564,
#   'rank': 'I',
#   'wins': 109,
#   'losses': 103,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'flBYIjjAQBFzEV0J1ojMcrgXR9WcjJmUuI77SCAWYUxAwE0',
#   'summonerName': 'TL Bradley',
#   'leaguePoints': 591,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_zfyAyFM9YhVU_RyBEeyXmjrMOQ6XIoq4h3B_ldiFraJH5o',
#   'summonerName': 'Strompest',
#   'leaguePoints': 614,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 62,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'niXPToxUKs3r5CxPV4oAU0bnoffMgCNv7NLdfmPmrx1tN2uEJYp3r_51cw',
#   'summonerName': 'FLY Johnsun',
#   'leaguePoints': 664,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 70,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'WIOrLe67LzPKIfnZuA2hQIEvJwvvH8lgYJFbMg4KBpiCc0o',
#   'summonerName': 'c2 meteos',
#   'leaguePoints': 844,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '-yGpAB0jasPEcw4IPfs4VuIoWpGJlwT4P_zzfIt3ByRinP8',
#   'summonerName': 'destiny9',
#   'leaguePoints': 598,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 70,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'wrz3zbNG7kdSg5gWoD23EDDRgaJ78qJjycvTXtUcfwcfDlCkR2aKPtXflQ',
#   'summonerName': 'elodragondotcom',
#   'leaguePoints': 630,
#   'rank': 'I',
#   'wins': 103,
#   'losses': 94,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'bg8v_f3ilL3m3rPbqU8FOa62HMhqtllxHnz5kHHwhIw8IDXyICluvFW35w',
#   'summonerName': 'rehcra',
#   'leaguePoints': 552,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 31,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '5ze7HxOTRzMR3addd1vLaXA2Gp7f_Sv2DO4b-1G8EhPIS8I',
#   'summonerName': 'DrewDozer',
#   'leaguePoints': 693,
#   'rank': 'I',
#   'wins': 77,
#   'losses': 54,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'AJNWgakstihO1RqeT-ZUzoibUvt6zaKy9x17V1-gRSJDMzg',
#   'summonerName': 'Rhite Wice',
#   'leaguePoints': 617,
#   'rank': 'I',
#   'wins': 107,
#   'losses': 91,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'QQCnmpNhISdbmIYLElwDw6Qf8OK6Pw1fxViFAQXgxMT-EUg',
#   'summonerName': 'Haru Urara',
#   'leaguePoints': 1123,
#   'rank': 'I',
#   'wins': 169,
#   'losses': 134,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'LOmndg4laQ3USIqip6fuytGyZIKczAjzNjcI1-uCjZxjGTw',
#   'summonerName': 'Dhokla',
#   'leaguePoints': 824,
#   'rank': 'I',
#   'wins': 70,
#   'losses': 48,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': '0H2lYYVKdEu8l57jdXwIwctCohOqZAKymyRetvX3t11UswimK4nuutXvUA',
#   'summonerName': 'MUSTACHEmanFIGHT',
#   'leaguePoints': 1011,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'nzJSutyfsDywgyx48CHK1nBxNwuZPSVSmm5G1itIDyrdxIDX',
#   'summonerName': 'Mojo Jojo',
#   'leaguePoints': 614,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '75-H5hnDhKRwJdHErF1_c52RUJCRwIICjAME9p5HoOFpulQ',
#   'summonerName': 'CarryingPB',
#   'leaguePoints': 512,
#   'rank': 'I',
#   'wins': 83,
#   'losses': 76,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'oquXeThrTRuZrhJ82JVnb6iKLAGvjGmwSkP4Sbxhvu0M3PoDJVhKsV035w',
#   'summonerName': 'Fei bo',
#   'leaguePoints': 500,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'TaIrZuBMzDSfNegeBLYdBUmoTFQ30A3ZiCivbk3fo7XeOfE',
#   'summonerName': 'Tony Top',
#   'leaguePoints': 501,
#   'rank': 'I',
#   'wins': 112,
#   'losses': 96,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'E_tv0Nf2yeTIgUK-zGiPLHg4hDQSR-WDi3kNollu7ON0wE1vhxod41b9xg',
#   'summonerName': 'HC kuaizi',
#   'leaguePoints': 508,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 75,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '_qmFb5CWKs83Bn1TFm-ICNMQTFN3Xv15GL4574dvOA',
#   'summonerName': 'Pobelter',
#   'leaguePoints': 510,
#   'rank': 'I',
#   'wins': 57,
#   'losses': 41,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'BLHybWHUeUEq78yLQClEFxR3olQcGo1eeJSu7ton_Sn3iRA',
#   'summonerName': 'kisno',
#   'leaguePoints': 757,
#   'rank': 'I',
#   'wins': 113,
#   'losses': 89,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '2L8jId54qb2KIm6bTODM-tU96FHImmmLetQoIqQyZkDk-n0',
#   'summonerName': 'Nikkone',
#   'leaguePoints': 617,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'wbfi-4AOrwcNraimshggaWuzoHMSAQAskDEGpvnxIpGWLHE',
#   'summonerName': 'Decøy',
#   'leaguePoints': 512,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '1DMLpOiTaTROsGm2Dyqdc_A_x9vUqArjTJLHDcHUNSLTzax6dJtj3wTGLg',
#   'summonerName': '1lyg',
#   'leaguePoints': 591,
#   'rank': 'I',
#   'wins': 135,
#   'losses': 109,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '1XbRvT6NgidFKPFYR9v9AbaxyogaZ-DYazzXOCVu4XDHnhA',
#   'summonerName': 'bryan3838',
#   'leaguePoints': 655,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'iJ7G3jZ5-sE1TfSefem0CXE8O9KN3CkpPEM4tDjp3qLToXk',
#   'summonerName': 'Dc EGC Taotao',
#   'leaguePoints': 486,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '0pYOpfkXcVuPccjhVbpMoIJpX6ZeKiSetsKXoAzm2MTrqIMr3V017evGXA',
#   'summonerName': 'bvoy3',
#   'leaguePoints': 692,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'njbEJdeRmFxHi7MrNVGEK0zGsjDwn5k0FhkZ3CYTRxKG26c',
#   'summonerName': 'MaxClub pw Kenas',
#   'leaguePoints': 973,
#   'rank': 'I',
#   'wins': 139,
#   'losses': 121,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '_r4I5OW_F799PkKilXLwhSlUCGP2tQzewjTGgoMY-uscjGw',
#   'summonerName': 'Feather Daddy',
#   'leaguePoints': 640,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 96,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Q0461rU1lzS8MWBNCeqYMSOTdtrL2OjFV9YJGMP1tanU8STZ',
#   'summonerName': 'spïritual state',
#   'leaguePoints': 513,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 91,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'cszJzOpWAMkIT28IB76HmlkEYNgpCa8sQ6IoJA1E3iyWW14',
#   'summonerName': 'Sepeku AW',
#   'leaguePoints': 500,
#   'rank': 'I',
#   'wins': 52,
#   'losses': 30,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'gDi9YUOSMnPPFZoCXtZNoZ8FeR-9YrM_-ikX586LbI6flvxOZ23o7cRDgQ',
#   'summonerName': 'The trdblaster',
#   'leaguePoints': 553,
#   'rank': 'I',
#   'wins': 111,
#   'losses': 80,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Y6qkufi8EEAwRmD3tKiehIDmc_iM4CK2v63hXSy4_uwC',
#   'summonerName': 'Ablazeolive',
#   'leaguePoints': 616,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '-HWKmTbHF9vFl-JxWa-T8HpGYERieH-MmAPmVzTSgLqjBS0',
#   'summonerName': 'Zyko',
#   'leaguePoints': 515,
#   'rank': 'I',
#   'wins': 87,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '4X5D9dXJ2h68v7I2lxPop0RCbt_mjXF197DcYVSTx3RwrtbF9fjRptA9lg',
#   'summonerName': 'TL Yeon',
#   'leaguePoints': 573,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 90,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '26C7xybXB1WieVDn8MBecIdaLw5ReVVHnZfYGFQ7TZaI1j92',
#   'summonerName': 'yukino cat',
#   'leaguePoints': 690,
#   'rank': 'I',
#   'wins': 115,
#   'losses': 111,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'DGrLhWsGVa2TwcfdDUwAFzeXfKTtdU2yILvfkCE-RT1Udng',
#   'summonerName': 'Likable',
#   'leaguePoints': 507,
#   'rank': 'I',
#   'wins': 80,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'OxaHf7hMZUDqnBTTHPWaqmCOhOXciFJztoar_Q0t9dsAs-E',
#   'summonerName': 'suffix',
#   'leaguePoints': 611,
#   'rank': 'I',
#   'wins': 113,
#   'losses': 95,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'yXEFJKs157YaqRW4kq0TGN-TOuSd5YpNp23zzsCs7VXA204',
#   'summonerName': 'PoopSwag69',
#   'leaguePoints': 600,
#   'rank': 'I',
#   'wins': 80,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'zBHSLlG5M0eIeTfvdomBgk4WZoUl44ZS-cmaBktIvfAW-Ng',
#   'summonerName': 'Wx Mjm978244659',
#   'leaguePoints': 1166,
#   'rank': 'I',
#   'wins': 100,
#   'losses': 76,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'mOA174xuPZZJ8kkNQzzvHOt1waAECd6DCsW0asDDtvCMy6g',
#   'summonerName': 'Karasmai v9 ',
#   'leaguePoints': 596,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 73,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'FpxD4VBCtYv1PdmeObp1W1IcD84JSHWI-8OxupyTWA8SdxAF',
#   'summonerName': 'Le JunMa',
#   'leaguePoints': 540,
#   'rank': 'I',
#   'wins': 80,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'I7NX9l6LqSQ5A2Y03Ocw6xEkZ31lXed12hX1COOpH8kBZEUH',
#   'summonerName': 'WX Rika19981209',
#   'leaguePoints': 518,
#   'rank': 'I',
#   'wins': 117,
#   'losses': 107,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ZiH9fMkG-gpa8EWu-M-orQIYY_emIVeBpO6oi06SP7Xm8gxyZbfl9QK17Q',
#   'summonerName': 'FLY Yuuji',
#   'leaguePoints': 752,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 48,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ViSzlmrK1imon_S-yN2ugtM62jG4aM6TMCv_QkSs9bDY9as',
#   'summonerName': 'DB was Here',
#   'leaguePoints': 515,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'emUDe2AOrBqjHIs1JP8-S7y9T4woXqXA-zCk-AOIRaKT2Ts',
#   'summonerName': 'Wynncraftian',
#   'leaguePoints': 542,
#   'rank': 'I',
#   'wins': 68,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'bZ3-qu-h5Izi1CBEHyxDfLsMbNzaMtJ92HybF2ofFIunptY',
#   'summonerName': 'NøticeMeSenpai',
#   'leaguePoints': 511,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'FTIu1qnyBdjOJHeTUzI0AGm7XNAWjo1oYwwX5stGUQ1U00qh-KZBA8ANfw',
#   'summonerName': 'ADD ON WIN',
#   'leaguePoints': 661,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '6gsT2zqM67mShaTObCeU_hGHeydHa_3XQDb3iiO3xq7W6fU',
#   'summonerName': 'TTV LegitKorea',
#   'leaguePoints': 574,
#   'rank': 'I',
#   'wins': 47,
#   'losses': 27,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'hVINt5Ih39g27OE6VaWL6kvL3z8jLgb7ppWoDqxExUXUR_Q',
#   'summonerName': 'Mobility',
#   'leaguePoints': 521,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 93,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Vb1uMJlE5RhrNbCa0oTMImC_dvl-OPw-YzSUBGkus-sbQvxJ1E8H9UufXg',
#   'summonerName': 'Eyla',
#   'leaguePoints': 641,
#   'rank': 'I',
#   'wins': 57,
#   'losses': 39,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '1yWAkSsNvfpFnwiL4S7WlyICNN3SABsA6QrDVbv2wZD14bQ',
#   'summonerName': 'KatEvolved',
#   'leaguePoints': 871,
#   'rank': 'I',
#   'wins': 118,
#   'losses': 107,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '9OsKGwjUxG1d6qDEw4y9lZEA2313WA39toOg1nEyeiloilc-',
#   'summonerName': 'Shrimp Cpt',
#   'leaguePoints': 921,
#   'rank': 'I',
#   'wins': 92,
#   'losses': 78,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'fcjBNN7-Cf-pebWxmkEVrtyS90Ktmsbho7FkrS4SGK_7BhQ',
#   'summonerName': 'emoyo',
#   'leaguePoints': 610,
#   'rank': 'I',
#   'wins': 116,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'WBAIYhL3Z5ijPlIjmpEb-NZTuaa9uB1cjUIHPgkNu1pp1UsqkCQdPbh1KQ',
#   'summonerName': 'FishIord',
#   'leaguePoints': 616,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'UwB90q3AmK5ez5Rjj0OKdJJIqluf_GqgtwTNdk9zli5zsbA',
#   'summonerName': 'DK21',
#   'leaguePoints': 991,
#   'rank': 'I',
#   'wins': 139,
#   'losses': 121,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'IAeN7ZejRkpIwpHE1LvKkEuQpR19mX_CjScovrsNWuf_iP8',
#   'summonerName': 'Charter For U',
#   'leaguePoints': 526,
#   'rank': 'I',
#   'wins': 128,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'dvy6BEYNNz-pqLvkSGCZd7nWziQmsuruz4WgLzKIOb_0qHM',
#   'summonerName': 'AnDa',
#   'leaguePoints': 758,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '1jbj8GLBB9WBVeAJQruWBEeULjfJN-A8j7OIYZ8bsGx9_iUZVgDtl1MjtA',
#   'summonerName': 'lens7',
#   'leaguePoints': 602,
#   'rank': 'I',
#   'wins': 88,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'iPPUWZztlyDhwIgNUSl4e-PvNTw5AFIMS5gFHVCSoQlBI3Y',
#   'summonerName': '120367',
#   'leaguePoints': 513,
#   'rank': 'I',
#   'wins': 100,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'MxzBGowhDv1ZzYrxsyj2z59Ai4iAzbrq7_-ILt_gQfrDTJw',
#   'summonerName': 'Int Overflow',
#   'leaguePoints': 514,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'UqBirvBF1KXnku85quJaECLmzHgSN_x8kZ0gNF6kjV-2Fa2V9ihM9DyTSw',
#   'summonerName': 'Hogang2',
#   'leaguePoints': 709,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'n871axKA7evxOVOhrI1Y1a_i-DarU8vk_5J4FZbUoj5PMt2P',
#   'summonerName': 'Flåshh',
#   'leaguePoints': 600,
#   'rank': 'I',
#   'wins': 162,
#   'losses': 143,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'fsY_jYgH7MrTQKgZS1S3CQbbKk4e5r9d3x2eDenO3aScaBQ',
#   'summonerName': 'Trieuloo',
#   'leaguePoints': 518,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'M4MbW9svR6YXtXOM72Q9E9WyHECOCzONFv7zCT7A85-4oEs',
#   'summonerName': 'Josedeodo',
#   'leaguePoints': 862,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'SgKaije3ymsNSeGO1ps_Z2fry4wXsPAomQqxDxTgIH8SaFQxd6bZ_8WcTg',
#   'summonerName': 'The Pulbarizer',
#   'leaguePoints': 508,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Us-emwApV6aDgN2RceVELFnLlS5LvQCAAkKT4tZ_Mdm2uCk',
#   'summonerName': 'UwU OwO Rawr X3 ',
#   'leaguePoints': 500,
#   'rank': 'I',
#   'wins': 60,
#   'losses': 36,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_LnMO5QWEjMABl9zKbT8x_P-dKWiyJgJbiCzINIpX1MbFpU',
#   'summonerName': 'IN0RI',
#   'leaguePoints': 503,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'THQNDCsSDOKu6ameEAqyzQEfWhKu2bGRGwhlGnHS859EotQ',
#   'summonerName': 'SnipaXD',
#   'leaguePoints': 517,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 90,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'JTIG9ytvlMbirIzh4gb9aDOysCafedjgfagj53BXdVj24Aw',
#   'summonerName': 'Geiger',
#   'leaguePoints': 554,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'uVFKbGFrpesds8NuFOBaZ7B92s3-JYgLBNcwdDeS4o_VVac',
#   'summonerName': 'MUNCHY1234',
#   'leaguePoints': 592,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '3BeSlfS6AtdZGy2LEIw7vm4m8GNp8YOf9XLJQxRYO5o4e-Y',
#   'summonerName': 'no invade pls',
#   'leaguePoints': 586,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'j0MT-o6tu1_vNH2TpgyCLfYmQKp8xm4ZBaPy6iXsl-XKKGyT',
#   'summonerName': 'ad player',
#   'leaguePoints': 742,
#   'rank': 'I',
#   'wins': 83,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '4sxLwMdO74-EAC5KrUaygi1tQJdisMraMcOE2fYvKAOW6Ok',
#   'summonerName': 'Logan Circle',
#   'leaguePoints': 513,
#   'rank': 'I',
#   'wins': 108,
#   'losses': 93,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'bhvLeTzH0xNtFHU6HHm5K1lrWKdG7VEKqUOHHRCoxaD0kjv5',
#   'summonerName': 'From Iron',
#   'leaguePoints': 675,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'b1ZjbKUb2ItAZBqXO6XcSO8PCIJT6cDG103rAzyzmEBAkKM',
#   'summonerName': 'Shiba lnu',
#   'leaguePoints': 512,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'y529t54JonBqKh8sjBzutvboP6IAZYay_vwSN1RHXfPvPsncnuz94r9Bag',
#   'summonerName': '767602',
#   'leaguePoints': 646,
#   'rank': 'I',
#   'wins': 103,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'MZXGMXwraSlFRcqftpd17m0zgVvMLQSosn2LF74S9MIZLjs',
#   'summonerName': 'Frenq',
#   'leaguePoints': 583,
#   'rank': 'I',
#   'wins': 98,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'WnLg0ErFslU738D43FNTGRsKcsCz1jE-KTao1GzH_H-fcqsN',
#   'summonerName': 'SOYFACE SIMON',
#   'leaguePoints': 500,
#   'rank': 'I',
#   'wins': 110,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'CAzxsLXz1SFQS9phCHFKpc3djnp3SaA5rNIVn7K4mx1p2sey',
#   'summonerName': '95440174del',
#   'leaguePoints': 542,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'C75lc0KWTEOBc-YsfEwzGtbEZxb_DdeV2S_PtbV8N7tDLgV39ofRiFnw7A',
#   'summonerName': 'Poyisama',
#   'leaguePoints': 639,
#   'rank': 'I',
#   'wins': 70,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '4hnlH_IAqCaSXCZHbjtrYw424-VaWnW-B6zFH9R-o6XtGcs',
#   'summonerName': 'Reputed',
#   'leaguePoints': 501,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'qAt3Jr1s2TEYHe7739NtUgP-2JBTpXy8uvrXJ88cE3Ixuz5KZJa4wslzjg',
#   'summonerName': 'Aaron Song',
#   'leaguePoints': 552,
#   'rank': 'I',
#   'wins': 93,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False}]

# %%
grandmaster_dto = watcher.league.grandmaster_by_queue(region, "RANKED_SOLO_5x5")
grandmaster_players = grandmaster_dto["entries"]
grandmaster_players
# Out:
# [{'summonerId': 'jB1fPcUpR2ncDB-3UZzvpR4fzUafY1ucXY9SlI9M06hANm4',
#   'summonerName': 'GNK48 saltyfish',
#   'leaguePoints': 226,
#   'rank': 'I',
#   'wins': 54,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Ybahv1e4DgiXucPDL3Ap1qBApjAdLbOvvTDWzMgSUWZ4RzGK',
#   'summonerName': 'TWTV AndresTexas',
#   'leaguePoints': 359,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 87,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Koq1onwOGFhx6gUcf3Edn5JtXlQOXPRVFFV6fKMHFV5NKBo',
#   'summonerName': 'with grace',
#   'leaguePoints': 323,
#   'rank': 'I',
#   'wins': 92,
#   'losses': 73,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '4Y7Y5BPcUK8HT8AdIFXIUyOURyKy0YQ8EnmpZWLWl1ffDKg',
#   'summonerName': 'Fioristaa',
#   'leaguePoints': 223,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 87,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '9ffNB9y89dC_CBac0hnKXUdC0xLGThyjohgeb9NAkhRGKwA',
#   'summonerName': 'perry1',
#   'leaguePoints': 204,
#   'rank': 'I',
#   'wins': 34,
#   'losses': 24,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'cIHF6yhx3Ofi8hY049D_4naivEjVRLW6BTL4_9ZfZGhXrvE',
#   'summonerName': 'Love Kano',
#   'leaguePoints': 269,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'PVjyyQFktQFHM3mkZxlyKLvVQl4q8CbrOK1GRgQo4yaMb74',
#   'summonerName': 'lafyèv',
#   'leaguePoints': 349,
#   'rank': 'I',
#   'wins': 51,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'wQTlmrqVTqhBKsJR522rnNUEiujGkrvwuzjSd8hmaSF1U5k',
#   'summonerName': 'Suddy',
#   'leaguePoints': 239,
#   'rank': 'I',
#   'wins': 47,
#   'losses': 26,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'j35Qn_ios95aW-_n-oK1irqqihvHaPVJRuetX-vY-G4yCTA',
#   'summonerName': 'Pooky Wan Kenobi',
#   'leaguePoints': 399,
#   'rank': 'I',
#   'wins': 100,
#   'losses': 92,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'KdNZA7vnIJm29YIWEActfEmmp6mKZW7iZLQTq_xJgJ8xGlE',
#   'summonerName': '  ßrüŠśÊŁ ŚÞrºÛt',
#   'leaguePoints': 255,
#   'rank': 'I',
#   'wins': 55,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 't_3gmLGFi33Zhnd0Sj3QJSx49v7iCncqW3Bqxvi_C7OTyGbZTyl4Z9R6hQ',
#   'summonerName': 'Philipe Ojomo',
#   'leaguePoints': 246,
#   'rank': 'I',
#   'wins': 68,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'WQtVoxShxorP-pEuQGw06F1qPvRwZu2xxQH8lAVs84pNya4',
#   'summonerName': 'from mcdonald',
#   'leaguePoints': 265,
#   'rank': 'I',
#   'wins': 30,
#   'losses': 13,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'tOxP6cXr7F2G0GlfrJnMGcimlOeuGmEgCddJypidWF2NZ-o',
#   'summonerName': 'NAsFinest',
#   'leaguePoints': 459,
#   'rank': 'I',
#   'wins': 125,
#   'losses': 105,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'j5cHaupoe4y2CvJL1fLYXUCyZHVYUjsGZ6-NwEfQd7kL3pU',
#   'summonerName': 'Pluto1',
#   'leaguePoints': 317,
#   'rank': 'I',
#   'wins': 52,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'GgnQtSML6WGBA_oJlFmKRDzW9lxItGOQDXHUy0Hl35m-mQ8R',
#   'summonerName': 'Queen IU',
#   'leaguePoints': 350,
#   'rank': 'I',
#   'wins': 60,
#   'losses': 58,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '_rrhVK6FtgxFaeDEM4Jrs9ND3Lp48G5so2ENncSCqJzjMyA',
#   'summonerName': 'jeremy2',
#   'leaguePoints': 508,
#   'rank': 'I',
#   'wins': 98,
#   'losses': 87,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '84gTeAmtAi4bMtqi8atn11W5RnTjt9NIDEoUBjOVqdOeC6s',
#   'summonerName': 'LittIe hat',
#   'leaguePoints': 212,
#   'rank': 'I',
#   'wins': 55,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'H2mN0HgKSY23CqSMHK2DYhErgX7-o3tsdh7VMlKVpLGbnuk',
#   'summonerName': 'Neøø',
#   'leaguePoints': 486,
#   'rank': 'I',
#   'wins': 52,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ym2bYuZQBQcl4kAtYdJHgsAjbRgeSuJGV7vC-8QKbt_LeKe-7HWwRQUGdw',
#   'summonerName': 'Chime2',
#   'leaguePoints': 248,
#   'rank': 'I',
#   'wins': 47,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Wag3NQ6C0cUMTaHTbdKW3uE_nVo1wJyDtS4-7NXN0rrXC1Y',
#   'summonerName': 'Strova',
#   'leaguePoints': 219,
#   'rank': 'I',
#   'wins': 55,
#   'losses': 48,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'o2PrMEAAZwifyuOHUlQ9Kkump7bx6PFhs2X0r2qN9fmnZLA',
#   'summonerName': 'MONSTER CHAD GOD',
#   'leaguePoints': 205,
#   'rank': 'I',
#   'wins': 60,
#   'losses': 67,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'lzL0cZ1p6maci0IGw1XqZR1G8bTzNHdaXGHRE6bYxQcLziEsPMrQdD2ddg',
#   'summonerName': 'hamadurumi',
#   'leaguePoints': 250,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ucFDhnVM3OL_D9yEAZaYF1ldfcLa_fmUUOBZoGgUjNl7aGs',
#   'summonerName': 'Cytheur',
#   'leaguePoints': 209,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 67,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'LgXvzlwK4olSJyYUIHfnWX-_sOnJO-_-qD3JKyZ_x8pE1t0',
#   'summonerName': 'aquanick',
#   'leaguePoints': 258,
#   'rank': 'I',
#   'wins': 55,
#   'losses': 41,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'n0jc4L9TZ2UF7Ri7qDzi537uw8iDNxTSycVlnFzltVlb2bo',
#   'summonerName': 'Draven baka',
#   'leaguePoints': 403,
#   'rank': 'I',
#   'wins': 77,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'dqm9yyDJnAWpDIyPFA5Rmcl91R8hDRp2lmeA-wsIu2SLxGQ',
#   'summonerName': 'Camp that Bush',
#   'leaguePoints': 346,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 59,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'nwX_fkwVhLC8khefVcbWTw3M88bWil4STX1pfwI84TRC--la',
#   'summonerName': 'Pet Dog',
#   'leaguePoints': 354,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'O_JJhtdk-42d_wwtP0bIbQnw_oOqvfdjkU5IkvFjCiKw',
#   'summonerName': 'admirable potato',
#   'leaguePoints': 263,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'bdn3FnzICyx1jgOTt-NtGAJTWpMtkcxp-5qQQFKW_DXRD69ngCFsvmdPqQ',
#   'summonerName': 'Protone15',
#   'leaguePoints': 334,
#   'rank': 'I',
#   'wins': 95,
#   'losses': 88,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_Tuv22W2xznMdKS1QdubPAFDJUL_BVaG0fkDOms-0_vw4qo',
#   'summonerName': '5tunt',
#   'leaguePoints': 318,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'SCRSJiDE2dMc5H7P3lhSiZiJo-NyfQqbFCcWZji7tFncJyw',
#   'summonerName': 'Fight me homie',
#   'leaguePoints': 228,
#   'rank': 'I',
#   'wins': 48,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'e-lNX5boJ_rrWmqC7zFEKEVCWvR30OEMmy4GrXbY25W4BRQ',
#   'summonerName': 'sponsorless',
#   'leaguePoints': 272,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 102,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'RXOVvtWFfEMj9kFIp1-Jv5YkEi0FRFHoye32OSjChKk7T5Ng',
#   'summonerName': 'FZXT',
#   'leaguePoints': 229,
#   'rank': 'I',
#   'wins': 52,
#   'losses': 40,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'mPXzq7s4d2w5slu7cDIZd718K6nxxxisGr2oJc_3UwrOIH8',
#   'summonerName': 'Regis Booster',
#   'leaguePoints': 253,
#   'rank': 'I',
#   'wins': 58,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Oxjr6764IvzIqQQaxsQXZPtz81bNZdiEqhbBV5h35TncCXc',
#   'summonerName': 'Aiden Yasuo',
#   'leaguePoints': 375,
#   'rank': 'I',
#   'wins': 53,
#   'losses': 48,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Ubgk6TBPn0qu_vppjmUd2NqQ4_N-B5ToP9HN3RihyUW-YP7E',
#   'summonerName': 'cosha2',
#   'leaguePoints': 299,
#   'rank': 'I',
#   'wins': 38,
#   'losses': 29,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'UmKSsxV-CvwhpfOusAaiC3yMcWtgeka6KHCROEQEQLJNK88',
#   'summonerName': 'Løgán',
#   'leaguePoints': 259,
#   'rank': 'I',
#   'wins': 87,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'uoYBGBypRTaxOPYmGy3us6cr1zNv4dAM8DjGgq9voOFo7RYd',
#   'summonerName': 'HighLimitTest',
#   'leaguePoints': 253,
#   'rank': 'I',
#   'wins': 41,
#   'losses': 24,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'qkiVpsrnbL5HFQ7C1fCRfWZhy7VBc8gde_RlzqaygnfSrDg',
#   'summonerName': 'Kross',
#   'leaguePoints': 205,
#   'rank': 'I',
#   'wins': 55,
#   'losses': 35,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '8ylMOswivOaabpeYF-uz51SNQJR9QuF0VeACsKs_ppUiAeSu',
#   'summonerName': 'gl ln mcdonalds',
#   'leaguePoints': 322,
#   'rank': 'I',
#   'wins': 80,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '0-79yS7h3a0sHfDZv68eFEGYRdadDybEZMm2_9UlAodBtDw',
#   'summonerName': 'Veerchand',
#   'leaguePoints': 387,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '-JLfPw7tSqtnj__vLzfCokOS1ClY3OLkAofTPpa7mZaf2TlV',
#   'summonerName': 'very gay guy',
#   'leaguePoints': 350,
#   'rank': 'I',
#   'wins': 48,
#   'losses': 34,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'u1OX4zIHMYCmPPS1PFwDxAeOsSrOHZ2eSHS85GvRxZ4Q5b8',
#   'summonerName': 'Abedz',
#   'leaguePoints': 352,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 67,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'g6BNIB1qbg-8qge81gvmMsxcpnRb1iu2BKhdKRcfqeZ73EM',
#   'summonerName': 'Detsu Sama',
#   'leaguePoints': 231,
#   'rank': 'I',
#   'wins': 53,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'fIvcZe_7NQFTMCQqyOSB1DaoNVVyhXRCnPrs8q8Y28AWtF8',
#   'summonerName': 'Shâcø',
#   'leaguePoints': 372,
#   'rank': 'I',
#   'wins': 209,
#   'losses': 183,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'A51cut6u7KEmseJGatPdIcJAsFGfQz4pgSUDYY0VmpdDHa4',
#   'summonerName': 'itzz Wags 2',
#   'leaguePoints': 221,
#   'rank': 'I',
#   'wins': 57,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'MfD-y6rpOVYNwv_fxOemXWJxQuBu6db7lYaKV2VuSKxB',
#   'summonerName': 'Silent Reaper',
#   'leaguePoints': 291,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'q09LdGtDQOElX7V-SqZ8p6J29xkESnleQngiSANcvAEZvnoa',
#   'summonerName': 'Bloody VaIentine',
#   'leaguePoints': 401,
#   'rank': 'I',
#   'wins': 102,
#   'losses': 87,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Ui5ENJ6ekrjZOc8cH1c_Ea-OFKswc8A51-gPn6cJDj-3FI4',
#   'summonerName': 'Revenge',
#   'leaguePoints': 384,
#   'rank': 'I',
#   'wins': 38,
#   'losses': 24,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '-fHSapwaa00qNFeADoyG6pSbO5itcEpqtcbp4nxBu1cL82M',
#   'summonerName': 'CHADWlCK',
#   'leaguePoints': 425,
#   'rank': 'I',
#   'wins': 105,
#   'losses': 91,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'an3Wp56JROT8cFswCmC3t-_M3E4SnCLjhFSaO68_aJk_0yc',
#   'summonerName': 'xXxLilPumpFanxXx',
#   'leaguePoints': 393,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'a6K0dMu2zHfZFud3AWGkxcs0x4aIS4gQ5JuePSrtJwhxbWc',
#   'summonerName': 'Caw me FTS',
#   'leaguePoints': 202,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 56,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'VI6WBeTeYqULxSIDl-4oBoynem9RSkojnD8tqnnEh7tIq41MH2WcOa5JJw',
#   'summonerName': 'R7 Luffy',
#   'leaguePoints': 387,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'VbLB837Zcs-bUJ83TewiBiphSnPHxd-eAInjHSZV6Ro0SCk',
#   'summonerName': 'TTV StrawHatAni',
#   'leaguePoints': 440,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'cEeEPjnKj_C_lgdSzTQOIZx6PhJhTXHmMrIMio1GgRd26PM',
#   'summonerName': 'Hakuho',
#   'leaguePoints': 330,
#   'rank': 'I',
#   'wins': 38,
#   'losses': 26,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '2NNB2xhHmAfn16K-DQyYPJwldLStx31sekwCJCOyCZgRmZw',
#   'summonerName': 'OliviaRodrigo11',
#   'leaguePoints': 267,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '3ZQoqnpiUNt0hN2lP4h6_xSUhX_qSdSduGtQxbDRBIXbqjE',
#   'summonerName': 'maximos',
#   'leaguePoints': 214,
#   'rank': 'I',
#   'wins': 34,
#   'losses': 19,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '-Zcjw9DBOkEuBB3ITyTrbJRq2VfMP2Rg17qADzSszvaavFDXtVC6LPGCMw',
#   'summonerName': 'hao de ',
#   'leaguePoints': 303,
#   'rank': 'I',
#   'wins': 51,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'PpHCTt_WVmwUn5Dl06CzmuZhSW6RIEXsKvAa_jgWIjNjd7jvb3D1MDDIcg',
#   'summonerName': 'tempvpqwqeiqtcne',
#   'leaguePoints': 408,
#   'rank': 'I',
#   'wins': 105,
#   'losses': 95,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '_hSzMJ8O2f7etD8Yi5rV65vUzEd7XmMnOFZYUxwMQbA0ud8',
#   'summonerName': 'TomMatoes',
#   'leaguePoints': 200,
#   'rank': 'I',
#   'wins': 105,
#   'losses': 87,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'z1JyHIQJb5QG_pxgwiiSyXwpUswc0R1R6awRLFV_xmIVT7tB63yzOqrtKw',
#   'summonerName': 'qwdasdsa',
#   'leaguePoints': 435,
#   'rank': 'I',
#   'wins': 70,
#   'losses': 59,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'D_V8VSKozATEVH7feU6zbbnaCE-4eoVcHqisS-TCpW60gJg',
#   'summonerName': 'Stiifo',
#   'leaguePoints': 244,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '5MCWuoCHCS6beB6mlPFgSnE39scVr3jFEesRM0ucI4hf6zdLAhBF4UZNKQ',
#   'summonerName': 'Bot0511',
#   'leaguePoints': 232,
#   'rank': 'I',
#   'wins': 45,
#   'losses': 29,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'PYRQdyW6cf05AAQzqm2oqcEwHgBK272nd5lFZbF-9VdcPML0',
#   'summonerName': 'TwTv Main Sup',
#   'leaguePoints': 203,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'M9Q41ASlmEa0bgRgPC4tT5cfhm_QlNCSUNhTxC4CsqXjwKo',
#   'summonerName': 'ADC I ONLY PLAY',
#   'leaguePoints': 415,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ms4b06ZjZ4TJXd8JEsKWi2sP-SzZR0BIekb0G4lDFJaYYTXf',
#   'summonerName': 'Shearrealtide',
#   'leaguePoints': 305,
#   'rank': 'I',
#   'wins': 105,
#   'losses': 99,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_n58OdyPCXlYa8wVbpqq3S2BO2XbOf_ZXcO9hdmMNtxAy8M',
#   'summonerName': 'Mr Bluehat',
#   'leaguePoints': 342,
#   'rank': 'I',
#   'wins': 51,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'aINaohTLTP831gTQPGZMjB_51_xIR92UAMmYl3YkvhX-cWyfYiJ-Ji2T7w',
#   'summonerName': 'TwTv imsudzzi',
#   'leaguePoints': 401,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 58,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'gq53M2YYz1buOc_VTH6zGAG75smUngMbTtDfeH3KKXWWsG8',
#   'summonerName': 'UF Fyrat',
#   'leaguePoints': 202,
#   'rank': 'I',
#   'wins': 44,
#   'losses': 39,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'OCrR2IxE5w9QKf5qrSbJC1e1AaxZyNnbr8ssbmjGHcN8YjM',
#   'summonerName': '            Tçº ',
#   'leaguePoints': 473,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 34,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'DyKw09Me0VePAlTVGjOkcp1kY0wFGFQM6V1fEqaEUD5UnRo',
#   'summonerName': 'Putilt',
#   'leaguePoints': 336,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'AhZxOZGzuMS0MxBRsCH1QDFOorz_MkfLosrmZiKmEq-dMB8',
#   'summonerName': 'warhunter',
#   'leaguePoints': 435,
#   'rank': 'I',
#   'wins': 57,
#   'losses': 48,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Hx1Niu1FeYa9JsOM5MSnxlv0xlLTN19QRYv2V14kyCKjHxk',
#   'summonerName': 'Srkenji',
#   'leaguePoints': 459,
#   'rank': 'I',
#   'wins': 59,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': '37rE0XO8JvPY2u8qCRUfkw2byhIRIzfR97BT0B6AgpFj4tE',
#   'summonerName': 'AbsurdlyFatDuck',
#   'leaguePoints': 209,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '6afpllsmdP8eEByt1V9XQ7XF-8s7_d3x32UZbLTxs_tQwgQ',
#   'summonerName': 'i stomp on men',
#   'leaguePoints': 204,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 90,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'vw5GK6auV23KsKFul40xE0LovX_RaXQI__eg05m011D9sHi-',
#   'summonerName': 'papaXmama',
#   'leaguePoints': 393,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 93,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'kq2CgUkdq4vFT2MuRR02bPtn2Cf7D3LliKlot1HYAhgvqNQ',
#   'summonerName': 'Anotherhope',
#   'leaguePoints': 265,
#   'rank': 'I',
#   'wins': 71,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '8_diK-Z1oF8FPjZyTbAal61IE5eCXaLKUtxoJSUd331QbKQ',
#   'summonerName': 'Seranok',
#   'leaguePoints': 336,
#   'rank': 'I',
#   'wins': 51,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'uwazUZrsgJO4Yq8V7VzttzL33wgwOcGBS8GMQ7rU9X9CYk4',
#   'summonerName': 'Yung Fappy',
#   'leaguePoints': 391,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'P7ZUqcByRWi7Qs4gUF8o9OYvFBL5Ls6vVdasu6u8fgdXPr8',
#   'summonerName': 'KiNG Nidhogg',
#   'leaguePoints': 384,
#   'rank': 'I',
#   'wins': 95,
#   'losses': 98,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'P0qfvjRejBYOrorZtSTcqtzm23Q_VVsUN54MH10VCICVOsQ',
#   'summonerName': 'Pinwinasio',
#   'leaguePoints': 367,
#   'rank': 'I',
#   'wins': 48,
#   'losses': 40,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '22In-GS3UaBvPb8vrjtZP90g3-EwSN5aVOaRu20b5O3jId8',
#   'summonerName': 'Matty',
#   'leaguePoints': 447,
#   'rank': 'I',
#   'wins': 71,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '6C-_Kj5xBl-JEULtzywd9uRuvGK0lZLpMXl_NElp7nCH9pUaMcZqD8wweA',
#   'summonerName': 'afmaoev',
#   'leaguePoints': 234,
#   'rank': 'I',
#   'wins': 43,
#   'losses': 27,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '6Vb-jfezIG1NKhdQkTzPa4aT6-5EBX85dwXPFrSIjZxvBd54',
#   'summonerName': 'S2 IGFan',
#   'leaguePoints': 208,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '9jG-F2pNAuUUNZJddZzorSxsi8aw_m7OqzrP-vLovyuHbU4',
#   'summonerName': 'Hesrew',
#   'leaguePoints': 253,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 89,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'n5cWBxgyM7QXwa2F3AdEdUrmLIq6jO9Fr5htj37NCe7T1NI',
#   'summonerName': 'xyxtommy',
#   'leaguePoints': 202,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'bvmPPNEBwbeRwcbJ7De1b7PlQzfh0YqnE4-Q0O-PQG9ZHlOgw2ZX2I6WdA',
#   'summonerName': 'Hasie',
#   'leaguePoints': 217,
#   'rank': 'I',
#   'wins': 38,
#   'losses': 31,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'kVStA9IM0ahbdcDkZXSg-u_MDNpTOG0-Wf744k2J9dh2684',
#   'summonerName': 'Dragoon',
#   'leaguePoints': 276,
#   'rank': 'I',
#   'wins': 35,
#   'losses': 23,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'R2203BTFgbHg6bccRCAiHCJA08z0mSoPdv_LmaIo1OQXDUE',
#   'summonerName': 'SexHaver808',
#   'leaguePoints': 388,
#   'rank': 'I',
#   'wins': 61,
#   'losses': 54,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'S3S-_i8MuUqQdd-U7lZWFsEpZ0XXLVBJhdKsR7ReOwX0c96h',
#   'summonerName': 'formu1a0598',
#   'leaguePoints': 427,
#   'rank': 'I',
#   'wins': 136,
#   'losses': 112,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'jrNqH8meIWV3eyz6Orysze5j4rsLPAg4bAaJzUjh5E0__Y0',
#   'summonerName': 'ATH Demy',
#   'leaguePoints': 424,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 67,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'S4ui_GHLt7GRA3uc_bNLmrmW3NLW_JxkbO4kvqRtieLNMfI_',
#   'summonerName': 'ADCADC123',
#   'leaguePoints': 308,
#   'rank': 'I',
#   'wins': 51,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '6i48JJncROEkf9KQd-8oydr4EpRFs9yfCvZ_PHFgN8qqlpw',
#   'summonerName': 'KryRa1',
#   'leaguePoints': 311,
#   'rank': 'I',
#   'wins': 38,
#   'losses': 17,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'cNDCBHr9brakVfkuFmWjETB8oV2kmSC1z9Clqx6NNOFN6PSZbyorGdUT3A',
#   'summonerName': 'ACKÈRMAN',
#   'leaguePoints': 374,
#   'rank': 'I',
#   'wins': 41,
#   'losses': 24,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'g4VeBdGDYgAxBP3YfgakrAtQrWyS8p7ygMty2cKqDxLqDralGh0moepPyQ',
#   'summonerName': 'EG Kaori',
#   'leaguePoints': 323,
#   'rank': 'I',
#   'wins': 58,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Q7cnUyYuGFPqhWr1Lh_0U8JFbW8kxXa-wsvRvpUzzwB-E2uhI0WiSc-61w',
#   'summonerName': 'soccermom12',
#   'leaguePoints': 360,
#   'rank': 'I',
#   'wins': 48,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'wZE9c96R16M5VL8Zv57IDV6IM4Hvh1CpZbmr8XQLm1D8Vddr',
#   'summonerName': 'TTV loljss',
#   'leaguePoints': 236,
#   'rank': 'I',
#   'wins': 39,
#   'losses': 28,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'lwO4EYMS39R0IvEHHnDityhb2hVz5_rjmzo5so8pe974WhTFAb_1rRgvvQ',
#   'summonerName': 'UW top',
#   'leaguePoints': 236,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 54,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'oIUMaqeIGmTfvn-UwK_YuOEK8-5m2rMVlied7OmdCHHEZ3M',
#   'summonerName': 'Fole',
#   'leaguePoints': 215,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'BFyz2Xm3Hmqb9gW674tDeGzwwS_-wLhn-vHiITpO29EH0sekwPMNhfANQw',
#   'summonerName': 'lmv1',
#   'leaguePoints': 255,
#   'rank': 'I',
#   'wins': 61,
#   'losses': 41,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '5RnZYle3ntFRHhrBFVHUI2Mgc-Y_br5aoi8RIq_IJN-l748',
#   'summonerName': 'Classiq',
#   'leaguePoints': 201,
#   'rank': 'I',
#   'wins': 136,
#   'losses': 143,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'gWgbgcIZTYMqfpDSCwfre0EBhscGarGDzbWDVdUTcgfPCRg',
#   'summonerName': 'Dc EGC Chovy',
#   'leaguePoints': 211,
#   'rank': 'I',
#   'wins': 126,
#   'losses': 113,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'Kgw3oWcifs5fJiM5Kj_uCXDis1A_El0m7luTvAMzrLRjkFU',
#   'summonerName': 'picapica',
#   'leaguePoints': 433,
#   'rank': 'I',
#   'wins': 107,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'GDjMJeaLm58qfTBf3D0QUPJmD6n3IFuFyrDAn-Kc-V07d5s',
#   'summonerName': 'rockonhi5',
#   'leaguePoints': 232,
#   'rank': 'I',
#   'wins': 53,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'MiiHi49qwyefc-U-HKyJ5uAtPWoqxRGeyAj9cE243OeZFr0',
#   'summonerName': '1xun',
#   'leaguePoints': 217,
#   'rank': 'I',
#   'wins': 77,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Jt_xP1YWIjV6NF0ZxH1e0SARK3zQmMGxG3jnY_fqBBMJ0iT1',
#   'summonerName': 'lpl top laner',
#   'leaguePoints': 281,
#   'rank': 'I',
#   'wins': 42,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'zKTDyG6Kq-dE_51DQzErvoYfe94dKFWLbOTsxERC4UDwNTM',
#   'summonerName': 'Prymari',
#   'leaguePoints': 301,
#   'rank': 'I',
#   'wins': 55,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'iiAeTeV7E1i0Vxhqypr6Np8HO6xUUO3BY-Nac4U7JuIJbOs',
#   'summonerName': 'Soldr',
#   'leaguePoints': 216,
#   'rank': 'I',
#   'wins': 88,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'UE79IRDGzajZorUtWAJrRQP5Qptq583K75SXGIT-AOQvEBM',
#   'summonerName': 'Ryuzu Shima',
#   'leaguePoints': 389,
#   'rank': 'I',
#   'wins': 67,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'J0Kjq3mYgQT3Gb01tiXBfLQu-U4pgNmb7alDigalF1-CdBA',
#   'summonerName': 'heechan',
#   'leaguePoints': 312,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'IUUln8r3EUBxuHeBYf50P6DGy6fclj3ZhPaolUT6PgMDW3qMQP93H857bQ',
#   'summonerName': '100 Sniper ',
#   'leaguePoints': 282,
#   'rank': 'I',
#   'wins': 40,
#   'losses': 34,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'qFfBTxHVT3NS8DYFRpIJdvBDhPCPLMnladpiHJ4xnxkyDrs',
#   'summonerName': 'rege',
#   'leaguePoints': 423,
#   'rank': 'I',
#   'wins': 109,
#   'losses': 105,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'eEZZzl-VDcYUWKeFc4_Z72V8MQ8Y_WumJXOXuAVXAVCIT68',
#   'summonerName': '777 IcèMango',
#   'leaguePoints': 280,
#   'rank': 'I',
#   'wins': 36,
#   'losses': 19,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'JeHctbuZ81fRk-haMdZlWGJmgqWqjqxxwsuwDJ2LUI5qzGc',
#   'summonerName': 'Rumahoy',
#   'leaguePoints': 205,
#   'rank': 'I',
#   'wins': 171,
#   'losses': 162,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'YHxrenn89M_8S6FPb-LTP8kxiTFZwV_No7Popv7bVHt8eHA',
#   'summonerName': 'Sam Screams',
#   'leaguePoints': 244,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 79,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'I232PAhy1gx_FbMZeiZgSvzIPNXXZ5H-uL0wxx3C-uQoRFc',
#   'summonerName': 'Schoonmaakster',
#   'leaguePoints': 279,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 75,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'tyrg6gngeJeuEKaDFGT4SdUIprKXTjBuzzInj8Z-0QTog-L9',
#   'summonerName': 'Anticípation',
#   'leaguePoints': 220,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'op--UGDPyByeHn9mH6msiCsElXKDkVxdsaqMHenDt-cPmqY',
#   'summonerName': 'Dandelion Yi',
#   'leaguePoints': 232,
#   'rank': 'I',
#   'wins': 55,
#   'losses': 49,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Jv_iPkn7T36oiaLHHgTpP1B53VLqus3IT0I1O_T2baBjlX4',
#   'summonerName': 'Nimdle',
#   'leaguePoints': 247,
#   'rank': 'I',
#   'wins': 36,
#   'losses': 22,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'bzHvc8LVarIDgCxJI_BQqzcg-wq_GKPpTuPXL4gKrKfH9K8R',
#   'summonerName': ' N L',
#   'leaguePoints': 202,
#   'rank': 'I',
#   'wins': 30,
#   'losses': 21,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'G14wbwdtV3V4Ww2u7HN48VRWyrS3Nv79bFtUABA76UJCc88',
#   'summonerName': 'SwordNoob Fan',
#   'leaguePoints': 207,
#   'rank': 'I',
#   'wins': 47,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'f_S-oSubNXXd4MZ7uWDWXa1b6e0PKQttkBX7wacWoHbjJHdY',
#   'summonerName': 'Wuhan Uz1',
#   'leaguePoints': 236,
#   'rank': 'I',
#   'wins': 117,
#   'losses': 126,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'fLI5IG1KHuOOdY2y69sfud9jL2nqBejZ3YiFb7Nn8pCEqLvmMwfcgOg3KQ',
#   'summonerName': 'agorinas',
#   'leaguePoints': 256,
#   'rank': 'I',
#   'wins': 40,
#   'losses': 30,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '47QLzeNyfxgQb1Jqb5lpCuZ3NT7MH0Hh0gdAKSAdjSbQ0AaKQMrB60YmEw',
#   'summonerName': 'TTV niinim',
#   'leaguePoints': 240,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '1wnJoRskV7N8Sd3nlrCtNQm0tIqqkUm1wX2ED2uDEXA9uaQ',
#   'summonerName': 'Diabloww',
#   'leaguePoints': 290,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 58,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '8feiQMmaIxOolYYF7CoDzk2-WUiUtYShWdtmy_vNXBBRCh8',
#   'summonerName': 'we boolin xd',
#   'leaguePoints': 298,
#   'rank': 'I',
#   'wins': 53,
#   'losses': 28,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '9kTfFMOeZ1AZgTMBcPQEwede844x-P9I0gMslbLWZH75xlc',
#   'summonerName': 'Froggen',
#   'leaguePoints': 304,
#   'rank': 'I',
#   'wins': 41,
#   'losses': 35,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'EAKaAnrjaOuSRoOQRcbQRHNzm12nqRYZpNYuZWr_b4k79DEsLtF90EwHfQ',
#   'summonerName': 'dark choir ',
#   'leaguePoints': 473,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'MG1GPQOUz00ojt2KdBNzr4bzwnonF-ZGTss2pbY5bRZldfak',
#   'summonerName': 'Ineza',
#   'leaguePoints': 249,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Vbr8n2CI0jiyRyyAOH2mN5Q1gxbVCYQ9ckbtiBlGcuou0og',
#   'summonerName': 'Blitz',
#   'leaguePoints': 324,
#   'rank': 'I',
#   'wins': 67,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'UM3YiJKULQJDsNvDGB1K5O5YPhVUtnkMCstqsIyssERN6wU',
#   'summonerName': 'ćam',
#   'leaguePoints': 300,
#   'rank': 'I',
#   'wins': 68,
#   'losses': 67,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'wNRLHCKoJW6wQUItx19Bhp-S_hkiIFxQRfV-UlDcT5rLAJGnKzzJaYGrpA',
#   'summonerName': 'Gustaberg',
#   'leaguePoints': 342,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 54,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'DUXUwCy3b5sOnr1ebcA2qfPsVs3EGkUDgYgiTmYLDALZCaA',
#   'summonerName': 'Łightshield',
#   'leaguePoints': 300,
#   'rank': 'I',
#   'wins': 149,
#   'losses': 150,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'f1co6IkjCB_hjvDV3mfxNEFsp5CsYeugMR62PbmaccQlc58',
#   'summonerName': 'billy worth',
#   'leaguePoints': 402,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'n4x9GMyx81qiK2UEBkn0_EgP9ceQeZbb86jpYEGGdbPQwf8',
#   'summonerName': 'feeder warlord',
#   'leaguePoints': 224,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 62,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'N3YjqEK-sPHcRtHb-3G6a5ug7god3roFfxhBn_FX59jPRvM',
#   'summonerName': 'Busio3',
#   'leaguePoints': 231,
#   'rank': 'I',
#   'wins': 50,
#   'losses': 56,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'HOC9R7fWbA4_0_BwpzdTQr2dPsRfsIH8mA7z8zzwZlEmCbY',
#   'summonerName': 'Fragas',
#   'leaguePoints': 182,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 67,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '2mQvtSyu313UHJj83owMFGyhPZFbZiGyvdVPMppr4B7lsnI',
#   'summonerName': 'AntiFaust',
#   'leaguePoints': 203,
#   'rank': 'I',
#   'wins': 41,
#   'losses': 26,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'WMsLYllbIqZCDqwGRENFAap6ys6PQR0qN8AXqdHwjAC66no',
#   'summonerName': 'Alyrezec',
#   'leaguePoints': 240,
#   'rank': 'I',
#   'wins': 88,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'BOHGqXWAqkKQc8bpv17Vs4AvK6bxbVk3_i3UDmNk_yk4TtDbj34Sf-ROoA',
#   'summonerName': 'Obeisance',
#   'leaguePoints': 215,
#   'rank': 'I',
#   'wins': 116,
#   'losses': 113,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'pp2N-LXOvGjd_rRTxD5zvBv_TzifGnSk7dToRS5LMroU6mxF4x4VXO6WEw',
#   'summonerName': 'KryRa 16',
#   'leaguePoints': 259,
#   'rank': 'I',
#   'wins': 31,
#   'losses': 16,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '9htFE1afEsZm4VuL3hKxcd36ePKq5cf0Ctsa_0t31lB_f4w',
#   'summonerName': 'TwTvUrUncleSam',
#   'leaguePoints': 334,
#   'rank': 'I',
#   'wins': 116,
#   'losses': 111,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'yN4kn0QL_tR05RtrnvKuRg7Gkck-6UeSj5qyK4ic9WMS_nc',
#   'summonerName': 'DC EGC uu',
#   'leaguePoints': 404,
#   'rank': 'I',
#   'wins': 87,
#   'losses': 75,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '9GPNNv3GbE0nrx4JNUldtztTlNiz1i9TcokwFBQ6VjYfScE',
#   'summonerName': 'AD Nannies Pref',
#   'leaguePoints': 401,
#   'rank': 'I',
#   'wins': 45,
#   'losses': 24,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'xT_P3bwAtmp3Ieq1lrQ9EhiY1-J3qPK4W1hfNzUUQZI41b4',
#   'summonerName': 'Jinx',
#   'leaguePoints': 400,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'oblB38cBGoSvPHZv4O4MK2ITkA7fyl3vsTgpnBMcPlhR9v8y',
#   'summonerName': '109 ms player',
#   'leaguePoints': 274,
#   'rank': 'I',
#   'wins': 59,
#   'losses': 40,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'fHjcJQrwfHFiLX_w33UfNfaBZetHfs8VNnm9eDlw8lpeDek',
#   'summonerName': 'Binkx123',
#   'leaguePoints': 352,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 59,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'GawpebAO_KeYrTVT_xOmbxK5zRcVBAtECj9hsZgIbZ_R4yg',
#   'summonerName': 'CATDAWG',
#   'leaguePoints': 289,
#   'rank': 'I',
#   'wins': 60,
#   'losses': 62,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ztBFuAjXqvbPWwRDBTIYH3XsebsR945p3D4TDoetPEIKcf8',
#   'summonerName': 'Jawshy',
#   'leaguePoints': 372,
#   'rank': 'I',
#   'wins': 112,
#   'losses': 102,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'WO-0hadOi5-xpq9ELt-y0JJrnx2i8QYr9cQgSBKQf-sKliK4lEuIDhm8ng',
#   'summonerName': 'My Zebra',
#   'leaguePoints': 443,
#   'rank': 'I',
#   'wins': 91,
#   'losses': 72,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'F0eBggjjpiczo0PqJF3oN5WRluAEfHEPgPo2BNWEiHq86HyVqolLRpL8kg',
#   'summonerName': 'Shibal game',
#   'leaguePoints': 353,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '49-m9EFg-j3yzfhCSlL3J8d5guTldIER4abfrWwovg3Roto',
#   'summonerName': '12ygt12yfwytfv1',
#   'leaguePoints': 427,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 92,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'OMG0bVTv7FYbGewqV-rOSFH90Fhw4Jy9aeKVeSYXU6OFl5Q',
#   'summonerName': 'German Lampost',
#   'leaguePoints': 296,
#   'rank': 'I',
#   'wins': 40,
#   'losses': 25,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '9v_bHvHGRcEC6-nQJ09JXZXBIHGdtW7bolmyJMGy233Av1Y',
#   'summonerName': 'KUROKO STYLE',
#   'leaguePoints': 244,
#   'rank': 'I',
#   'wins': 53,
#   'losses': 39,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '3_MYz6QLZrUHATfkvSYDxkers4UwsjNXs2g8wExBmj941qE',
#   'summonerName': 'mohanno',
#   'leaguePoints': 419,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'zxAjRn2wKqK8cojfM9xPG7saz19ig8gAChSAC0J8npqZIAPZ8j2X4D7vWQ',
#   'summonerName': 'eL eL TRIGGER',
#   'leaguePoints': 190,
#   'rank': 'I',
#   'wins': 59,
#   'losses': 54,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '9IIseYdj641X1CMHdwtt6LWlZnlHhDwXrJDddPzkgU26ZcVdi6swqApvug',
#   'summonerName': 'UF Reaper',
#   'leaguePoints': 261,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 67,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'GwX7zMyc6MP5wTl-2RO5SrIHevI7JhwK9jMvwItN3QtkDD4',
#   'summonerName': 'cupcakes29',
#   'leaguePoints': 439,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 54,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '1tRqIcZoXbgW_Grxr82ie6PX4XGHQ9HdObqhVlSNe-c0onzd',
#   'summonerName': 'Faisalll',
#   'leaguePoints': 324,
#   'rank': 'I',
#   'wins': 44,
#   'losses': 34,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'gIIOinOyMM2g39IgrewZG_lM9aZfYhOTrwUIXDje9UUAXec',
#   'summonerName': 'Young Tactician',
#   'leaguePoints': 348,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'K1aaT8gRl5PAnzDRJMXxCdoRtI4HKhf5VKjZScXSeWO4dCkb',
#   'summonerName': 'Doaenel Hecarim',
#   'leaguePoints': 323,
#   'rank': 'I',
#   'wins': 91,
#   'losses': 88,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'kslNVKZ3kaWkwFGXDvFY4TkKTIVWiEHK3Mo09B3a7gb8qNPTxXuhCjRyeg',
#   'summonerName': 'BLADEROMANCER',
#   'leaguePoints': 359,
#   'rank': 'I',
#   'wins': 110,
#   'losses': 81,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'jtziFsloKXiD-BSVHW3J-9qnonl4Nckc_amhCFCjsA9E-XA',
#   'summonerName': 'Laynx',
#   'leaguePoints': 290,
#   'rank': 'I',
#   'wins': 60,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'zjyXLoAjbjQsOOtPAFreDfFd207UzZImvDQDbUtkjY6l8x4',
#   'summonerName': 'Gmandlife',
#   'leaguePoints': 300,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'ZK1vYUvGRNhSi6jw4NWj_V6PDi--e09UvdeQSftpG-lGq74e',
#   'summonerName': 'Spooky',
#   'leaguePoints': 456,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '6gfRlwNKKGwPLke2zQcOt2Tfl8D4KV5NqeuMitSIGs5D1M2-',
#   'summonerName': 'kai fú',
#   'leaguePoints': 464,
#   'rank': 'I',
#   'wins': 48,
#   'losses': 27,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'VKtgCUN5If8b4wtbQYKcXNHGKJ47ZuMrJg2xUkQt_ooiM1g',
#   'summonerName': 'Bíg T',
#   'leaguePoints': 434,
#   'rank': 'I',
#   'wins': 107,
#   'losses': 99,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'dra6qu1-beSGq4kyUb0hqtNWpME1jyTKSIj6sF7-kOczix4',
#   'summonerName': 'Fiku',
#   'leaguePoints': 223,
#   'rank': 'I',
#   'wins': 58,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'TDGG2r_ZILJqfLwdZqPskjtBqwqtUZLP8KUVugbyP9SiMFA',
#   'summonerName': 'Le Kachu',
#   'leaguePoints': 301,
#   'rank': 'I',
#   'wins': 52,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'p7LEBASHBeTeTnmtSHALvRyQQO-1VIJeuW89cwPr3oec9c8',
#   'summonerName': 'notfinebutokay',
#   'leaguePoints': 246,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'FLw5QMMf9z9G6UiqvZ8S0b_60zGtXuKFmLFgJeKHO9POGko',
#   'summonerName': 'ALKSJHDLKCH',
#   'leaguePoints': 409,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 90,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '96UV7YMpdH-AYdlA-0A3AQMngWLr7iDOMtKC2SmCxO_sHRg',
#   'summonerName': 'Snoopsss',
#   'leaguePoints': 213,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'quE7IghM5hufCmdaxoZKuuRX9uWQoNfC0iIzROv1dicNblo',
#   'summonerName': 'Cadenas',
#   'leaguePoints': 241,
#   'rank': 'I',
#   'wins': 34,
#   'losses': 17,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '0guf8y11kZt7hN1GolrzH9skAGU02zBYgboG5QxKGx12eK8',
#   'summonerName': 'Competition9',
#   'leaguePoints': 421,
#   'rank': 'I',
#   'wins': 83,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'mU3PnulDwl2oqWqtjwUGFbN6a5yCwkJ_EG21DN0WYNK2G0H5',
#   'summonerName': 'TTV chenchen53',
#   'leaguePoints': 403,
#   'rank': 'I',
#   'wins': 63,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'VY-QCzG9EoOYxqS07nPHRRVlUuNGWljd94Zr3_y_20F98zs',
#   'summonerName': 'Hoàng º 2000 ',
#   'leaguePoints': 244,
#   'rank': 'I',
#   'wins': 41,
#   'losses': 30,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '34GDqPEVjDLJlVz14Guoa5JVDjCsgbiIlpJ-hjqxDn4JsrlNg4s5FDeP_w',
#   'summonerName': 'Delete All',
#   'leaguePoints': 453,
#   'rank': 'I',
#   'wins': 98,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'jaGWgQHK5AI5HgtYGSA7anavvDlrkv3mPQTzeS91ebRyUEE',
#   'summonerName': 'iybc9o2 q',
#   'leaguePoints': 367,
#   'rank': 'I',
#   'wins': 70,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'U1C81XPXMFjWA50lKi9BSOr5PyOek2M3Zly7BYOiS7l-YJg',
#   'summonerName': 'Ssumdayday',
#   'leaguePoints': 354,
#   'rank': 'I',
#   'wins': 44,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Qhb_XSISt_ZqzQahRUS6z5A3GtLe8_uyepqLa960h7WsYKo',
#   'summonerName': 'Memes From The 6',
#   'leaguePoints': 213,
#   'rank': 'I',
#   'wins': 37,
#   'losses': 23,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 't_2hBskTUfTz_zE6kL4zdy202nu8ylEMqpjn95Lpsr2_0cc',
#   'summonerName': 'SentFromAboveE',
#   'leaguePoints': 244,
#   'rank': 'I',
#   'wins': 52,
#   'losses': 41,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '7MNmEElJGRbfCaWq6dvhcG3QNUpdR-1eIuqF8vEVYmo6YT8',
#   'summonerName': 'Omly',
#   'leaguePoints': 249,
#   'rank': 'I',
#   'wins': 54,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'gCDY4rVNjOuRsCYQRMWqZk5MNLq02MJ_I_679r5u47D8oRA',
#   'summonerName': 'Yorushik4',
#   'leaguePoints': 441,
#   'rank': 'I',
#   'wins': 68,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'MM7QV9wgImLYVR1C5F--ftcIcxCleDyTiF3pjJQahwnqXCU',
#   'summonerName': 'LowPsyco',
#   'leaguePoints': 203,
#   'rank': 'I',
#   'wins': 77,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'cwvmUyKGZQ6qwFnda5VJ6yd4W-KTgCgMUJh25_iLmnKmkcw',
#   'summonerName': 'Blue Cherry',
#   'leaguePoints': 212,
#   'rank': 'I',
#   'wins': 58,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '3lGgpn0kVTbKy3iO6TWjr9TEtuvmWuoSKc_Dz_ghEmww8IL_Tcj3TxFPow',
#   'summonerName': 'Doopliss2',
#   'leaguePoints': 379,
#   'rank': 'I',
#   'wins': 96,
#   'losses': 93,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Oulb7o42O5h1Pz7-8POlJ6cmidyC6pkjYfY-_-mGInILrMwSwpR_jiG1Jg',
#   'summonerName': 'tempmesyfnyiskkw',
#   'leaguePoints': 375,
#   'rank': 'I',
#   'wins': 50,
#   'losses': 30,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Lngw0qXIAW14vH_rGI6JGVd4oBfhyTUYsAKrnpExOx7FUzqnIXn-_pY_qA',
#   'summonerName': 'Gen G Aden',
#   'leaguePoints': 305,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '31goCeBI7RoOBxFYjSM94EEN2C7Hs8ABEO2pW6hFNHuyens',
#   'summonerName': 'Kevy C',
# ...
#   'summonerName': 'Modus Øperandi',
#   'leaguePoints': 443,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '5yB1gMzc23TY1Sj2UGG1ZoDXdsXTXtBs9iPAFS6raKLp57lsNZdViMvMuw',
#   'summonerName': 'LeonaSuppPlsI1v9',
#   'leaguePoints': 324,
#   'rank': 'I',
#   'wins': 50,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'l_6igYzOqwlrzQ_X2461ZRrJr9bSY6C671WrtnWVgeftCaE',
#   'summonerName': 'Yasuhiro Takeda',
#   'leaguePoints': 240,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'GXTcRq5h-ow-OxBEV1D9-7VdGoEqfa2h_1fjRoCTdwizwco',
#   'summonerName': 'TRWHZBZH',
#   'leaguePoints': 218,
#   'rank': 'I',
#   'wins': 52,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'sbaJubP56qLo7da2FPPNh7PRZn1DjwLaI81M3h10FBpt5EQ',
#   'summonerName': 'BukZacH',
#   'leaguePoints': 276,
#   'rank': 'I',
#   'wins': 61,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'WGiX5O09PDN63BfMmmZnGXcmPKUL4OmPj4_isirq0rbTUDw',
#   'summonerName': 'legands',
#   'leaguePoints': 380,
#   'rank': 'I',
#   'wins': 102,
#   'losses': 92,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '11wFD6G1ZG-DPg0ukjGkITtULnB9Ug8ZjT4pIfbuTExiVebvhDhkTxcYZA',
#   'summonerName': 'Eve MV',
#   'leaguePoints': 235,
#   'rank': 'I',
#   'wins': 55,
#   'losses': 41,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_Ts-Lj2UEvrxyvZPEt_i6LcxeB9Wri7w59YHpDMcRckSOdnA',
#   'summonerName': 'AhernxPt',
#   'leaguePoints': 468,
#   'rank': 'I',
#   'wins': 61,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'jHwavkqo_mXhqtqE_zgBeEmWQBStEhJlJSVehiN0H0fR4Io',
#   'summonerName': 'thechoosenone',
#   'leaguePoints': 390,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 35,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'fhOiZeUyTH3RwA0Nvd40txWgGSILayG5vjCUjdnK9C9dnzZbQGxfvQ_Edg',
#   'summonerName': 'Pooper Josh',
#   'leaguePoints': 215,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'T40t1xuIMoZY527Y8ras0P9PSxWl_2ArWGmt3lND0_Nv-sA',
#   'summonerName': 'Subaru Natsuki',
#   'leaguePoints': 231,
#   'rank': 'I',
#   'wins': 44,
#   'losses': 36,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'zOPBQoV3lVWWfPJAKJOOxZa1nuB8DOIfOHCNsTyqNJE7_7I',
#   'summonerName': 'bigfatjuicer',
#   'leaguePoints': 250,
#   'rank': 'I',
#   'wins': 91,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'OdH7YrKkP3x-49Egj80NA10rhRlHa1CVk7YpEINIpNOxFL8',
#   'summonerName': 'hoidro',
#   'leaguePoints': 217,
#   'rank': 'I',
#   'wins': 37,
#   'losses': 27,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'S_wLEApSx2txlqfHPUPwIq1Llr4_dlAiMUg88DbqtfaD4gY',
#   'summonerName': 'EricZYang',
#   'leaguePoints': 261,
#   'rank': 'I',
#   'wins': 96,
#   'losses': 101,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'vkyH_a_Dblt2ArJhrUcbXZrk21nHkCxOXnJOGTMH322M7Dw',
#   'summonerName': 'RHINOOOOOOOOOOOO',
#   'leaguePoints': 350,
#   'rank': 'I',
#   'wins': 38,
#   'losses': 28,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '9l-UO_jQoiQZ3FL4w-_e13uIPl9fCLY8VZiAUBcPrYpDgbPbQidk9292lA',
#   'summonerName': '4399',
#   'leaguePoints': 303,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 75,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'qks-uiGXyAuEoWzL4GRtHynKzODKkl4qA27I38hamkD9090',
#   'summonerName': 'Accrue',
#   'leaguePoints': 201,
#   'rank': 'I',
#   'wins': 70,
#   'losses': 62,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'A7AAc7sJs1Sc9KjBDpGslaVU1WLGt9BnoKwkRlxNS27bHLlo',
#   'summonerName': 'MaxClub PW Star',
#   'leaguePoints': 255,
#   'rank': 'I',
#   'wins': 83,
#   'losses': 87,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'gnHo9-LEbPGhLKBSJ6-LA7BMZT5wSXYgGLl-fMl-Q93k5E9m',
#   'summonerName': 'aknid',
#   'leaguePoints': 273,
#   'rank': 'I',
#   'wins': 54,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'dgSXPRYc4mHCx7Wx9LpgwT0jL0wlGvF0RCHeJ3wqF_Yszs4',
#   'summonerName': 'Nim Chimpsky',
#   'leaguePoints': 407,
#   'rank': 'I',
#   'wins': 55,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '02sAvM5sZ1RcWbOXkvX9qNmaazUd2wxwwDcaLQ-2hxa_1XVO',
#   'summonerName': 'Deformed Jungle',
#   'leaguePoints': 223,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'ilWnPSV-QsLYvgBVqzTtfV9nMtLZWz4tJWTHFqNwt5O7Qqo',
#   'summonerName': 'Laurentiu',
#   'leaguePoints': 214,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'ZrPMevYiDRhYlU0YD8fxzXl0piV93e08y-cndJ9mdzK0-_k',
#   'summonerName': 'LittIe PP',
#   'leaguePoints': 204,
#   'rank': 'I',
#   'wins': 98,
#   'losses': 87,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'OKGFmpK_CzeEjwNZUXOz3fSlcotNqYuetxxzeWq_i69Y9IM',
#   'summonerName': 'Swüm',
#   'leaguePoints': 214,
#   'rank': 'I',
#   'wins': 42,
#   'losses': 29,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'Yn2XWgu4WE7ks8MxakDT9d338KWGQfhQvhRRJfyeXSs54Ss',
#   'summonerName': 'dotot1',
#   'leaguePoints': 281,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '0yB69Obf73vEW2UNuE1yoEYY0uT5brpjLRV315vHiJv5Oks',
#   'summonerName': 'UF yuwu',
#   'leaguePoints': 306,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 48,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'wuOds-b76bk4RYR-yK1QOY8nudxFhtvWcqaeKeQ1ywdQKGo',
#   'summonerName': 'JąY Løve Kąt',
#   'leaguePoints': 254,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 75,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '_s1Nh8GaRc8lH08MBBsI0tsQDxyDPF6bK3a-hn4muhcpjHGB',
#   'summonerName': 'EG Srtty 1',
#   'leaguePoints': 454,
#   'rank': 'I',
#   'wins': 52,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'P7a2FPzpIUdzCbUARP4mCmf5IrLLkrY21YI6d2lFdq-d43E',
#   'summonerName': 'Zilean Billion',
#   'leaguePoints': 200,
#   'rank': 'I',
#   'wins': 39,
#   'losses': 26,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'uqtCzxJCRM0c5wuegQwMrynlAsNGlBmV3lwYh3ehwqFowHUB',
#   'summonerName': '0 n a t ',
#   'leaguePoints': 446,
#   'rank': 'I',
#   'wins': 139,
#   'losses': 139,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '9TmDupGYKbSaB_gi1A8xoupXfwHPtF9ooR4IRUmR8FUpUr-7xX0A7zlEiQ',
#   'summonerName': 'mid namaste',
#   'leaguePoints': 468,
#   'rank': 'I',
#   'wins': 48,
#   'losses': 31,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'rubczOj8eNNyxWXzPeA-YKR2YQkct72UnGTb4-uKQGO7i28',
#   'summonerName': 'Tempos',
#   'leaguePoints': 505,
#   'rank': 'I',
#   'wins': 109,
#   'losses': 104,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'OVP2Dd8o4S9hUP6oMeue66U79hJweQy1r15DJki7Z7UGnp6O',
#   'summonerName': 'SlayerSupremelol',
#   'leaguePoints': 264,
#   'rank': 'I',
#   'wins': 45,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '83qFF5bT2qcKa3JkPQ7KYh7YEwZC_BEgI7XtSYQvBddJu9w',
#   'summonerName': 'rjsdndgod',
#   'leaguePoints': 424,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'qsm4EwKPm4vhu5Y9wNVzyezMgLUbNgu38Mw040lsDO_WFL0',
#   'summonerName': 'EG Impact',
#   'leaguePoints': 227,
#   'rank': 'I',
#   'wins': 46,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '9YyQWgfk3IBd3p8_-z3e4wZqfhZdfJf17iytLfnrfPiIIr4i',
#   'summonerName': 'Artoria',
#   'leaguePoints': 399,
#   'rank': 'I',
#   'wins': 103,
#   'losses': 87,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'obkyePS9GbaluZz-DfwDz_57doFtbLOfD13UIvO8LkjeZohPekd4t53ZkA',
#   'summonerName': 'need some Iuck',
#   'leaguePoints': 334,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 89,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'w7MR09LvzUbekT0FjCk96E5NSs1mUpxOEWoXgNhlb5joZxo',
#   'summonerName': 'Number2Ginger',
#   'leaguePoints': 218,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 41,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '2nnOw6Xy5wsniPtxif3-svzK_FWgxdDModOy_84MlD3tghhj9J3DTOk9Tg',
#   'summonerName': 'TL Hans samaa',
#   'leaguePoints': 455,
#   'rank': 'I',
#   'wins': 40,
#   'losses': 26,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_I-4_0dS_Ayhq-2I_aiZGuUIIG_t-k2dcehu6MOUuLof0zg',
#   'summonerName': 'Doowan',
#   'leaguePoints': 218,
#   'rank': 'I',
#   'wins': 57,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'hEv_F4TEYvfeuL-9mbKOL5Tr52MKcG9SK0aF2WY0v0qJxFyV',
#   'summonerName': '100 Donbray',
#   'leaguePoints': 211,
#   'rank': 'I',
#   'wins': 34,
#   'losses': 24,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'X5zslDD8oOk9bQKwHUh5i0UGgUHmRsoSY-r3CDWZ-xwuSig',
#   'summonerName': 'Sôra',
#   'leaguePoints': 201,
#   'rank': 'I',
#   'wins': 47,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'M8gdre4OOLNA7fGNBTfrw09-pwmKhZiX4cQfqE6Zd5Pz6SM',
#   'summonerName': 'badjglerxd',
#   'leaguePoints': 422,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'dR4z2toAogfNm-5Cnbza2a9HOWdJiXLXPZuAyksueqrrydA',
#   'summonerName': 'Vanos',
#   'leaguePoints': 440,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Yw4mf45nR3XhU-QLxWV6MuM3SrlwfyVJjbiXkItORbY2LCRW',
#   'summonerName': 'Hypha',
#   'leaguePoints': 203,
#   'rank': 'I',
#   'wins': 109,
#   'losses': 107,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '-TL4FJotDFb3uDWYExetuE8-yod8_c0VuqGdyieI3P6E62Q',
#   'summonerName': 'Daisey',
#   'leaguePoints': 280,
#   'rank': 'I',
#   'wins': 124,
#   'losses': 104,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'XWFP7EBjKROSnjaQmPgLrC-bgyrRYZLrFe7hG-Av3u_TXyCY',
#   'summonerName': 'TOXICCLOUTCHASER',
#   'leaguePoints': 203,
#   'rank': 'I',
#   'wins': 91,
#   'losses': 58,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'ZPkjF4fZUvdmVNfmqHPihjeas6fQccdS00rAihmiy7sYG4mMPHhiWvNwOg',
#   'summonerName': 'shxchi',
#   'leaguePoints': 423,
#   'rank': 'I',
#   'wins': 43,
#   'losses': 30,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'dXngD3J5_5D9AqLCBqiZ4cR-XR4ZvfGEUn9vjqrDPXoZmwMP',
#   'summonerName': 'Largente',
#   'leaguePoints': 424,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '4wsoqPAFOJ114XXBCRiCNI1z4IBThZ_j7kzjix7E-tclrmeYZyhWlxV48g',
#   'summonerName': 'Pentaless1 TTV',
#   'leaguePoints': 339,
#   'rank': 'I',
#   'wins': 39,
#   'losses': 23,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '5nfo-Z08bvcqGie_WhNDuIx8zRBtrJWAuAuNK1V5KwRv0YnX',
#   'summonerName': 'Yonsi',
#   'leaguePoints': 273,
#   'rank': 'I',
#   'wins': 68,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'TCXzgh5HoQ_emL3V4uHjp9v4SyAwXyDg-_7zAbe1J1AgEjo',
#   'summonerName': 'sean twitch god',
#   'leaguePoints': 445,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '5XTZuSSVA3kJUKmlON7_KgZejpaaPqRaM7iboyUVW43FUAQ',
#   'summonerName': 'CallHerMara',
#   'leaguePoints': 412,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 80,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'N7n3H9IcEkn3PyTZ72yS48Et0s5MwHn_5E7WaV7nnzEqZaY',
#   'summonerName': 'Qitong',
#   'leaguePoints': 351,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 70,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '2QWWxe5KXSaS5Q-0yCSoWIvk1JcFooFbBev4zFDB7T6mugM',
#   'summonerName': 'Le Punisher',
#   'leaguePoints': 267,
#   'rank': 'I',
#   'wins': 48,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'LIH3bBHLeRl4UqR3VfgW7ANs6rQvolsIwvzV5qau1HwDSHW6',
#   'summonerName': 'MEKHI0',
#   'leaguePoints': 366,
#   'rank': 'I',
#   'wins': 45,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'rmslUxhltlYIdmYnRgtpltvnRvq6MPVr5oSlpCXjHgxMuBo',
#   'summonerName': 'Mei You Qing Xu',
#   'leaguePoints': 286,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'uqdV475sWolLxSxcmypMcQwkWAjwt9IeqH4Sl3trnF-00xw',
#   'summonerName': 'xWind',
#   'leaguePoints': 233,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 79,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'bMJNv73CDHDpcMdkpJdsiHXANenR8aYur8HrpkYgmHGlfJ8',
#   'summonerName': 'Lauel',
#   'leaguePoints': 302,
#   'rank': 'I',
#   'wins': 58,
#   'losses': 48,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '0Q83yU54lwFyeWyACwIK0XJ9PnRUa9-eKj04ZK-tDxVlHq9K',
#   'summonerName': 'PastIsJustAGhost',
#   'leaguePoints': 331,
#   'rank': 'I',
#   'wins': 93,
#   'losses': 92,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Eyh-R771Cedq_KeuGN-WaYtEqtw-Gp3r21w9G-MhBM8GLvb3',
#   'summonerName': 'uqu',
#   'leaguePoints': 245,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'HiYQA8ez52exc3jdE-Y1tkSy61LKBvNIXCiBO3W8S58h5WwMgqfZVHLXFA',
#   'summonerName': 'Always Against 9',
#   'leaguePoints': 205,
#   'rank': 'I',
#   'wins': 38,
#   'losses': 28,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'N02uzlugdqCzxeuLrK0J6-zQ6lbJSf-ODyvDCz85wQ-vikk',
#   'summonerName': 'Suntail',
#   'leaguePoints': 304,
#   'rank': 'I',
#   'wins': 70,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False}]

# %%
master_dto = watcher.league.masters_by_queue(region, "RANKED_SOLO_5x5")
master_players = master_dto["entries"]
master_players
# Out:
# [{'summonerId': '0kBa624pBKapx0Y2MywP47BXcwNI8TYHu8vOC9uASFGQ934',
#   'summonerName': 'lG Roookie',
#   'leaguePoints': 55,
#   'rank': 'I',
#   'wins': 36,
#   'losses': 29,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'w2723PtXvp6j5AziWtKR7qpSbj6nZZdTJkG_DPat140OqdY',
#   'summonerName': 'Hiccup1357',
#   'leaguePoints': 165,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'tIQPAQILkEFlrsbvZzo6Tll5OEpKXwTnViPdemmrwXgcVuPE',
#   'summonerName': 'janna prıncess',
#   'leaguePoints': 6,
#   'rank': 'I',
#   'wins': 37,
#   'losses': 36,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '0QJmd3ShDLeybm16JT2s6tl5EvpKDnB7lXDIcCxM2qcYBnU',
#   'summonerName': 'Loopk',
#   'leaguePoints': 6,
#   'rank': 'I',
#   'wins': 55,
#   'losses': 67,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 't4dWVJ9z1Np27KTeiJBmBdn2uTkayOAJq9TilzL2Otuanjw',
#   'summonerName': 'SweetPete7',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 21,
#   'losses': 12,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'M5jubadpKsr_WR21YqG48wLxYa0owMkM92AZ90Sr9F0ePFo',
#   'summonerName': 'Ozami',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 47,
#   'losses': 30,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'gWTo7HCfD2JKJfvKJVL-qvYxnTgwldAE0jap69ye4i4w_qo',
#   'summonerName': 'Pure Genesis',
#   'leaguePoints': 4,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'cG2NfNn9WqptmIhSPrlzeMjojMZY_FtxNyGIHsQMqY9uhUo',
#   'summonerName': 'lìonheart',
#   'leaguePoints': 40,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'DN6nIxG37EWkh0VLaY9bq8Hy4haGM1vydaGyTuf9OGlz6Ds',
#   'summonerName': 'Zile',
#   'leaguePoints': 104,
#   'rank': 'I',
#   'wins': 47,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'bWTo_eLZq61pU0aVQHDJ4it8hZjGcHnE3Ab4V4UDdFnLYjGHAfsOFO8rCA',
#   'summonerName': 'Gnutemil',
#   'leaguePoints': 121,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 91,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'KcmAro8hLYzddCq7_BY4T9HKRilowMpTMXDFfU4qJ5FFsmw',
#   'summonerName': 'Taffys',
#   'leaguePoints': 157,
#   'rank': 'I',
#   'wins': 137,
#   'losses': 140,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '1CXWjioViB6F3553CQ88IKg27zA9hRmdFtTX3UkzMMO0xf0',
#   'summonerName': 'Trundle Top',
#   'leaguePoints': 41,
#   'rank': 'I',
#   'wins': 20,
#   'losses': 9,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ZnnzpVAwllTBGividKT1jXMahPjOXk6UZWWfii9KP6GC1jW83MnP5cxlWw',
#   'summonerName': 'Chapapii',
#   'leaguePoints': 88,
#   'rank': 'I',
#   'wins': 38,
#   'losses': 32,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'nwPOOkwwLGzM8oRQFBn7f2LBIl-CMGX9sNusba2tNyoP-1s',
#   'summonerName': 'Ruinsonia',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 18,
#   'losses': 8,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'BbsZAvQM-NncP3k6jreEfRpalVJBwZnJL80Raj3XKsQAIYk',
#   'summonerName': 'foggedftw2',
#   'leaguePoints': 137,
#   'rank': 'I',
#   'wins': 50,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'iz6O8rk-GUKJsPkFLWOvK8i99BEfcpzNGvaxWdQyYZE5e2I',
#   'summonerName': 'ninjasinpractice',
#   'leaguePoints': 74,
#   'rank': 'I',
#   'wins': 51,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'dYY6dC8yd-KW5rKz01KzlEpyUF0brng83sP5LXZ12Ovsg11eFO2eX8TPdQ',
#   'summonerName': 'Mimage2',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 26,
#   'losses': 24,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'VTGqMacQI2eVXEF0gWutFZPQGQ0pwxuT08tyEojmDO_Tz2XZ',
#   'summonerName': 'Dear Vista',
#   'leaguePoints': 111,
#   'rank': 'I',
#   'wins': 31,
#   'losses': 23,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '2sCYG2lw0-g34iXh2S8tuAiOKMgr5GZ85X6R3vB8Z2mKJeo',
#   'summonerName': 'Dinkey',
#   'leaguePoints': 103,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 62,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '7f9weQw0_8-UZ5OBGbpjWz1sPucmy3OfDGhjptK-hYM',
#   'summonerName': 'BR Lord Semi',
#   'leaguePoints': 98,
#   'rank': 'I',
#   'wins': 25,
#   'losses': 16,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'cQcDV89sZyXuYDr4ExnOs2oYf-Sqa5okzsicBKg-RHBJx3g',
#   'summonerName': 'JLand',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 29,
#   'losses': 29,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'lwTtDCaonxS-qbzD40jQsbPuPInRRiQnitEAbuZxTKfyeAI',
#   'summonerName': 'tingling',
#   'leaguePoints': 181,
#   'rank': 'I',
#   'wins': 96,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'VQEyJGOj_3pOVRagSapIasgd_OoSLqfJhoE9JxVP_seViko',
#   'summonerName': 'Mélos',
#   'leaguePoints': 189,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '8ljXoSu7doZXgGuSGLBBQkUgzTDDSXlk5-77b_9CVbnto30',
#   'summonerName': 'Hapre',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 29,
#   'losses': 24,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'BcEIR9CZ1yffFLuYz_7j-l7sNv9cEWdHGO9SGXrmdi7_lUY',
#   'summonerName': 'Luciferium',
#   'leaguePoints': 37,
#   'rank': 'I',
#   'wins': 65,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'KUh3CEPbtzyjOGj0r6JR73z-A6akslzImWDPRJ3Luk-h87TH',
#   'summonerName': 'vampire queen',
#   'leaguePoints': 15,
#   'rank': 'I',
#   'wins': 67,
#   'losses': 72,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'zqg7dnarvrb1OGtnQJHv-pPeOtfLorVANynJBrLeL9XaNkE',
#   'summonerName': 'exoffon',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 36,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'Q06xWm5dHbPjnVXbKr6cXRKc29vVzuk_9aBywifISeMRxz8',
#   'summonerName': 'Raeghal',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 38,
#   'losses': 28,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '4aRsfqmQPNHlt78KRDQYLP_kKmgrMBSppnjiRycfrA6Xd_8jAsKLytvkaA',
#   'summonerName': 'say it over',
#   'leaguePoints': 179,
#   'rank': 'I',
#   'wins': 38,
#   'losses': 23,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 't-PFh6tBzWKqbWHep7l84QMH6GeqYW5Y6FLO_4dKbPXaP4A',
#   'summonerName': 'zhubikiller',
#   'leaguePoints': 125,
#   'rank': 'I',
#   'wins': 57,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'E08hsWPGgUlH17qZBda-b1h0AT_oO3ULYraQvyJ0sscnpbw',
#   'summonerName': 'RockyTSaws',
#   'leaguePoints': 36,
#   'rank': 'I',
#   'wins': 30,
#   'losses': 24,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'A0EQFX9tmF5hMJ4aO5f6kfSpPgPieavO81zbvNmEBmjIs8zc0CXZ8YyFzQ',
#   'summonerName': 'øYubee ',
#   'leaguePoints': 14,
#   'rank': 'I',
#   'wins': 21,
#   'losses': 19,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'N8YprwHYzgO89nz0r9ZHMlUgyEzYEibP4t4feD25QkDMl_A',
#   'summonerName': 'CrusherCake',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 23,
#   'losses': 18,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ci6vsOgncpCahlt6m_Ox8W4v_VMQxuUOgfBuS1TSRCZwsS4',
#   'summonerName': 'Castleˉ',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 23,
#   'losses': 18,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '7W4fKFI-0-IKUt8ek-vCOy8y2IX-gf5EOZpxDgc2VTdyeRU',
#   'summonerName': 'Sabiñ',
#   'leaguePoints': 55,
#   'rank': 'I',
#   'wins': 33,
#   'losses': 32,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Cb7QvUdBXgwe7P-1PYfvHYnVzYwynYAzDl4CcwwRmlhkVhw',
#   'summonerName': 'xo Mystix',
#   'leaguePoints': 100,
#   'rank': 'I',
#   'wins': 51,
#   'losses': 36,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Nhd-Z6Vi2MSl39MqSjqiOaXmyxmMf9HxqbWAOVueB8zjRFE',
#   'summonerName': 'Lowest',
#   'leaguePoints': 102,
#   'rank': 'I',
#   'wins': 32,
#   'losses': 15,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'ROwmJ2iTFqZnFjrqVvSSjGokJ_4fGxMc4OoZQLcQd4fcbxg',
#   'summonerName': 'TSH Sariel',
#   'leaguePoints': 176,
#   'rank': 'I',
#   'wins': 96,
#   'losses': 99,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'IMmNYHCxmYreyhLMt_xpNgLXARk6O8pX9HBB4-_MYX7PgG8',
#   'summonerName': 'DomeThunder',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'u1KpnYNPXeaZLomOrqqihn7stBvQgwzIT0eQsbf_vFzbEqg',
#   'summonerName': 'meowmoew 12 3',
#   'leaguePoints': 66,
#   'rank': 'I',
#   'wins': 32,
#   'losses': 28,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'OHsPrLprhSVWihkmpTUgj8-J57UFfOwdv8_oLezwTewYZjk',
#   'summonerName': 'Shrugz',
#   'leaguePoints': 26,
#   'rank': 'I',
#   'wins': 160,
#   'losses': 123,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '5DZFxUWiJ1Pg0itLGhzUeZbvqsoJZUEIlRfyZBBWxJFWNhOc',
#   'summonerName': 'TwTv lolreppy',
#   'leaguePoints': 152,
#   'rank': 'I',
#   'wins': 46,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'FuFi-ZhPv0-WHBoo53VexKUSJblWj0CTNiAvagOXGdQtQGrkd_Y1BLYdRg',
#   'summonerName': 'TEAMFIGHT OR INT',
#   'leaguePoints': 15,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '5h-qJ6KvxDaixP0Ascz8igKI2UNqkBpQOFNGfxzSLowe53o',
#   'summonerName': 'Nànami',
#   'leaguePoints': 201,
#   'rank': 'I',
#   'wins': 44,
#   'losses': 35,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'M2GwP5prPAm6Om0J_cNVaKZJz7vjQ167Iu18S1QJMrYw45U',
#   'summonerName': 'Truesay',
#   'leaguePoints': 85,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'KFVhMwXpdJiQUeHyyTDJo7KJmbqq5MP1PtL2JppqoFbT1m3w',
#   'summonerName': 'Nai Cha Xiao Zi',
#   'leaguePoints': 87,
#   'rank': 'I',
#   'wins': 52,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '4OiILhTueWA8cMcvvBDYS9zDBbkGl9JpQpBwD2bu2qxwH8s',
#   'summonerName': 'ÃñÐý',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 26,
#   'losses': 26,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'ws5HVATizCprYsRnhC54ygrRe4gH7ZF-nwL1xOuSAdGSngs',
#   'summonerName': 'Emprisonner',
#   'leaguePoints': 107,
#   'rank': 'I',
#   'wins': 30,
#   'losses': 27,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': '7kC90YCPnwhB_ZMNFtxU3rChhnNIOrchvWCKxHkC31VM5RPI',
#   'summonerName': 'AK7',
#   'leaguePoints': 44,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 35,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'okc7-CroudM59hkQBij1aI9dFFv46I52H_YO4dpdiqOQrqBm',
#   'summonerName': 'NIGHTMARE JG',
#   'leaguePoints': 200,
#   'rank': 'I',
#   'wins': 92,
#   'losses': 88,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Mbx343Io14SKBAS6wX53iv1cRfAgJq5qzXzNYuztMhCJjuM',
#   'summonerName': 'Santorini Panini',
#   'leaguePoints': 90,
#   'rank': 'I',
#   'wins': 23,
#   'losses': 11,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'oIsKaA8m3k8CIkLoAia_w6fcpSZxNQ-43V2KK9GzE6lHWx4',
#   'summonerName': 'Pøng',
#   'leaguePoints': 18,
#   'rank': 'I',
#   'wins': 67,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '3TCWWYxVNGL5KkgvWmJ7vf-9nj8dxi5nKasnMzlfSuRVcc6e',
#   'summonerName': 'Børøs',
#   'leaguePoints': 3,
#   'rank': 'I',
#   'wins': 47,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 't6c8lY5-Q2AoChFEeMjmgI5WGRNI7-pdX8pZjrKGxJw3q1nthGOBHSnXQQ',
#   'summonerName': 'TL Kold',
#   'leaguePoints': 105,
#   'rank': 'I',
#   'wins': 39,
#   'losses': 24,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'NXO4BAIDf3LvCJRgnhAwKbtpL4KFh3o56D0apHg2Dg_CxPrN',
#   'summonerName': 'Rey Jean',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 53,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'CBztWlgdSMlxbnuoN3rj22byRuJWvvv4_WU7Av3lWK7g7uE',
#   'summonerName': 'I Am Chanman',
#   'leaguePoints': 38,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'zaDvNqOOEkczEc7KxAIDbkyih5xo73JpsAJVgPuLU6NOG8Y45vew6Gnv9g',
#   'summonerName': 'SVMMY',
#   'leaguePoints': 167,
#   'rank': 'I',
#   'wins': 48,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'aTQh7L0YwUnEScynP1ZqJ_G3h9a5KP5F4Xdc99qJ9DSa3SA',
#   'summonerName': 'chuzday',
#   'leaguePoints': 36,
#   'rank': 'I',
#   'wins': 46,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'Ppbm0JEMcvvwCSoisXqsL8A_qmexa_wIydJFuDGbTQ_-Fdg',
#   'summonerName': 'ZzLegendary',
#   'leaguePoints': 19,
#   'rank': 'I',
#   'wins': 39,
#   'losses': 27,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'v5LatmtqiFBQhU3hLlmliF3agiaYAkWnU8LEWJt0_v_nTCrj7KF2ugQQng',
#   'summonerName': 'qwalsdper',
#   'leaguePoints': 184,
#   'rank': 'I',
#   'wins': 42,
#   'losses': 24,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Z9XLHy4Dx9AXsJ0Ru1LmaIiDGOa33UAvQDRwoQ-rsc10TbRT',
#   'summonerName': 'Crit Or Miss',
#   'leaguePoints': 59,
#   'rank': 'I',
#   'wins': 46,
#   'losses': 41,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'IF93MggZBJVWO-gSbrfwGX0kkhbpO5SB97-hiVXbNyOf4uB5oUXjKqT5Cw',
#   'summonerName': 'Deantasanto',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 25,
#   'losses': 19,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'xHaw-hxp2OA1wf12no9a1-YK_A6Ku2fn_n5gYTmT0odE-YY',
#   'summonerName': 'Your Ruined King',
#   'leaguePoints': 107,
#   'rank': 'I',
#   'wins': 40,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'r4UKerewwOiBLUm_NWywnaZZyd6juLsQZhPOFjLw2WCI-qvu',
#   'summonerName': 'Timeless',
#   'leaguePoints': 49,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'CqDlT58GwtdtuYHuMWFng-nSeVsrBtBMsY6Svoa4GbKFXPNR',
#   'summonerName': 'stormzy x skeler',
#   'leaguePoints': 98,
#   'rank': 'I',
#   'wins': 36,
#   'losses': 35,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '9rFrDhgiDCXplEioRldtpTt8DjewrsK4VyPE5LoLj2EypA4',
#   'summonerName': 'Oronuke',
#   'leaguePoints': 98,
#   'rank': 'I',
#   'wins': 31,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'B6rIsk4d2cqUV3fSGLbGwVCrL13OV8cNM7y6ox7QyS0QPzE',
#   'summonerName': 'Euphorian',
#   'leaguePoints': 18,
#   'rank': 'I',
#   'wins': 39,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '2XT8t5Rpu8v_WEVHZfQDQO0Jzu4t7W0vZ7LdrPLwj7UOgEk',
#   'summonerName': 'gaozi',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '0yuosYdlK9xt2FTIDHmxCxPZ4tbnchjJIcxmpRU8HzOe5pU',
#   'summonerName': 'Backuping',
#   'leaguePoints': 108,
#   'rank': 'I',
#   'wins': 33,
#   'losses': 22,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'WtLJaN6WdVv4Fo1iMKdnpYXVyvcf_xsY-Vyfvoy_CxJxZJGlojnUzYJYHg',
#   'summonerName': 'Reeeeeevennngeee',
#   'leaguePoints': 71,
#   'rank': 'I',
#   'wins': 33,
#   'losses': 34,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'HPlJBg4240rGqy-Kx2Yz8YVxmwiLZIIoc73KP_dwGTx3JN0',
#   'summonerName': 'Sorenair',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 59,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '-iO4AUJ3yEZOx0w1Kf8FaN58n47POAM4gq-HxPbyW2cnStfX',
#   'summonerName': 'TILTA NAO',
#   'leaguePoints': 95,
#   'rank': 'I',
#   'wins': 28,
#   'losses': 27,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '9Hvw1kHLPcNoWo5-JlUnxhmrug1VsZ_JDbNwjkLiKzkC0x2xzUnJwi53Gw',
#   'summonerName': 'temphvaatkwkxgjj',
#   'leaguePoints': 38,
#   'rank': 'I',
#   'wins': 36,
#   'losses': 25,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'bdevoLMFVMqtiEa9OBivGChB20MM8Mh-3rE4teREmAjm8yM',
#   'summonerName': 'Mu Bu Zhuan Jing',
#   'leaguePoints': 108,
#   'rank': 'I',
#   'wins': 40,
#   'losses': 19,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ernQx1p6Ed01wWG-_UHkAySQTS989Hx_O2JcXkWZ8PMxsyqCFm7QzLNdHg',
#   'summonerName': 'eg jojo',
#   'leaguePoints': 244,
#   'rank': 'I',
#   'wins': 35,
#   'losses': 27,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'OMqT6FLn2XA2YXr29hSGfBRIBAclvoy0-omdWZSEW-2Re1w',
#   'summonerName': 'Messages',
#   'leaguePoints': 151,
#   'rank': 'I',
#   'wins': 38,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '1AD6YyYvZqvXoaacy9mLN0dpLecoYPeJWimJocf5xxsV5-M',
#   'summonerName': 'Melt in Spring',
#   'leaguePoints': 84,
#   'rank': 'I',
#   'wins': 80,
#   'losses': 63,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'ifeUPkszq3-OsqFZBBCcSe6nDCcahhdNqfhuLiG8t9osabEX',
#   'summonerName': 'htagv2',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 73,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'XO_6UrU_UiojX6WjPi5OBNKK3PGbpqXEd_HFDBFiXzAudEc',
#   'summonerName': 'Quánlì Yi Fù',
#   'leaguePoints': 17,
#   'rank': 'I',
#   'wins': 163,
#   'losses': 154,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ROlv9Kz7x_AnydVwXTP_SbIT2CY2LKrtXoTWl4mb-FdvZCU',
#   'summonerName': 'GoldTurtlez',
#   'leaguePoints': 27,
#   'rank': 'I',
#   'wins': 40,
#   'losses': 19,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'kbSZX4aVSgG7JcNui5bUOcpmZOg0yiNuiBw4gRRxSpvVYn8',
#   'summonerName': 'BL00D rush',
#   'leaguePoints': 68,
#   'rank': 'I',
#   'wins': 44,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'mS5XvPhguwnKq1N5CMmaYmZQYVP3FsqvKfXIc9G2muszZHs',
#   'summonerName': 'ÄLL IN',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 21,
#   'losses': 9,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'mGG08x71PQ4Imi6aejIIcgrcs4Io0FxZNFOlZvv4M0MIVmk',
#   'summonerName': 'Małłi',
#   'leaguePoints': 25,
#   'rank': 'I',
#   'wins': 45,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'vbK2JYB3gwBi7gmLz_btdRFo2zmRcatY-iiiD2A2f-i9fxCVZ5wxLH_rfw',
#   'summonerName': 'R7 Ceø',
#   'leaguePoints': 155,
#   'rank': 'I',
#   'wins': 41,
#   'losses': 35,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'vhdW4j0wmGOgaByf2yRjf8JhNqbLoPawrJns_xp7sPFM3tA',
#   'summonerName': 'egirl magnet',
#   'leaguePoints': 5,
#   'rank': 'I',
#   'wins': 54,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'cJ-yrFI7LmX3kaDpZw1Pbw5KPWurcZ_qmW68rp8gXU59UfCESLuTSYHDOQ',
#   'summonerName': 'xiang nian ta',
#   'leaguePoints': 180,
#   'rank': 'I',
#   'wins': 45,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '833E2pPkdHOqYk9TCZK1K5DeZeSEUpA4XtPGiegfxZfPY8Q',
#   'summonerName': 'alvinchangrocks',
#   'leaguePoints': 172,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 82,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'f_XziPdXl_XAEpU8-zwWxCw8vzmDsFCqucvqKZckaTrzdZU',
#   'summonerName': 'Blamed One',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 18,
#   'losses': 10,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'L91arH-zIx1UNDQDReYsdX0I7_yHQwNp6zBwPqjV5SygQCnb',
#   'summonerName': 'heietouzi',
#   'leaguePoints': 3,
#   'rank': 'I',
#   'wins': 29,
#   'losses': 25,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'GHZACqw-k1v3MqZAuziWdi_f4IHQFsP9iULgaOE0nEaXuoE',
#   'summonerName': 'Stach',
#   'leaguePoints': 108,
#   'rank': 'I',
#   'wins': 59,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'WiNNdkR2qwxbMB9kLe_sYbzUPqboLDNYzTGPoeFm93KjIec',
#   'summonerName': 'RexRequired',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 21,
#   'losses': 28,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'y_80WbRQfpMKf0KvtSWA1AYQ1wNG4NVxGFDPta7khLmZpt8',
#   'summonerName': 'GFÞ',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 41,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'jFb1eCOwgH3Cufwa0x5fSsAhnlv-gf9gxxWgCO1xyqYgavM',
#   'summonerName': 'Vultix',
#   'leaguePoints': 112,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 90,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'kCvApIXRnCoIUj9F9xM0jbe4-RxoOB-0rzcaDImJ8UTVfxc',
#   'summonerName': 'Anzhelika',
#   'leaguePoints': 20,
#   'rank': 'I',
#   'wins': 34,
#   'losses': 22,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'rS1X4NxA_worTy8EH340vQRG6QCgQbXF5N0g9AJ3nt6X06Q',
#   'summonerName': 'Tehpwner188',
#   'leaguePoints': 86,
#   'rank': 'I',
#   'wins': 63,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'PepS-LgVinyESkkkA_hjA2MwrjZ_u_y-KQl-6-hNTcCyvsoU8kDtGKtNpg',
#   'summonerName': 'FPX KLAUS7',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 41,
#   'losses': 22,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '3pcNAButvGfpgGBazN1Rc-nw8z-gnH1k4i5WNrj22GFYDhA',
#   'summonerName': 'Sean Innes',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 57,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'lpFyx84c5_NlYoIvsy-A40sEnXK9BCePUk7KNaCNanol_TE',
#   'summonerName': 'KennyMasterLin',
#   'leaguePoints': 42,
#   'rank': 'I',
#   'wins': 25,
#   'losses': 21,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '9AbPGUvApSOEZs0dEi1A-7NBrjEfaiLoIbBdMVAirTmvkhdNmwqOg2I4AA',
#   'summonerName': 'Abril April',
#   'leaguePoints': 41,
#   'rank': 'I',
#   'wins': 33,
#   'losses': 28,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '-0epDcIWjOtkDl1EU8dNqyD5hlTl8tJdrHJnb2mTkvdc9pQ',
#   'summonerName': 'Slamx',
#   'leaguePoints': 14,
#   'rank': 'I',
#   'wins': 61,
#   'losses': 59,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'i7tIxZafTW75S5TROpyf12lRqZ3-EAAVw6SuroLNE63zHO33',
#   'summonerName': 'Slyther6',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 20,
#   'losses': 13,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'HIsHBXtAc1DOX5Xzs0OR7fnzp3YvGibv0MSbeBoywVM',
#   'summonerName': 'Leoto',
#   'leaguePoints': 75,
#   'rank': 'I',
#   'wins': 24,
#   'losses': 18,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'I5t_2wSQp4hKjpaer2xlBm9lhCxKz9t0cfnX4baZHcv1JLpo',
#   'summonerName': 'Trey9',
#   'leaguePoints': 187,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_HYrdPAuzatvHQzFBUNRMCsyzX7-95hF4zdTVwejUn_ZiEs',
#   'summonerName': 'Ziz',
#   'leaguePoints': 44,
#   'rank': 'I',
#   'wins': 54,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Op5kPgxMjImEsMC6HGSbVqWx80MLGGO8gO7iQYIm_KmOPI0',
#   'summonerName': 'Gåstøn',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 30,
#   'losses': 26,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'jcTUrtuvUw685da6hjyTSeGI5fzRJ1HhJQhfTvkwlfO_c8laqk_Rwx4HjQ',
#   'summonerName': 'AZE Jungla',
#   'leaguePoints': 2,
#   'rank': 'I',
#   'wins': 32,
#   'losses': 31,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '0JnBEiiUuU5zK-43QSs5ke5L48i45AykcOPsVwq8X5S_Lm4',
#   'summonerName': 'Gojo Wakana',
#   'leaguePoints': 105,
#   'rank': 'I',
#   'wins': 110,
#   'losses': 102,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'dfO3ubV8HxxKUj2jNUKerrUQ4IgJQ1-aWaaDFuKyngoBmkc7x45XdkLUuw',
#   'summonerName': 'Bxy',
#   'leaguePoints': 144,
#   'rank': 'I',
#   'wins': 28,
#   'losses': 21,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '8UVdMU_KSbRwhA9XlWB4NR54TirLePd4hRzoB-qiKzRZ0hM',
#   'summonerName': 'Miseviv',
#   'leaguePoints': 20,
#   'rank': 'I',
#   'wins': 50,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'a2RToR7YaxLjULIBKdD4qunyWcND7p9M966c1VVQmkuvI80',
#   'summonerName': 'Yorick Is Bae',
#   'leaguePoints': 102,
#   'rank': 'I',
#   'wins': 101,
#   'losses': 81,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'jvfzGcrAfNta5PXsmVYtpVgT2WYnChFpU5U1yN5Q0D04-Zo',
#   'summonerName': 'Le Hanni',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 43,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'BwbCMe2wfzpPEYBTUQIn48EmS7rlbz1T0osQ7R4woQlLI0o',
#   'summonerName': 'Sean Nelson',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 45,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'NxeEYPelyR8meKmLvPQ8Das4yFhp2OQsndQqnzEH23dZ1Wc',
#   'summonerName': 'Fafn1r',
#   'leaguePoints': 52,
#   'rank': 'I',
#   'wins': 42,
#   'losses': 34,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'KNQgPS3m1B9hGI5AHfzDcPsT568FgMWV1rnx2Q8FRN-fKeXLAIYvxfyR7g',
#   'summonerName': 'NEW CHOPPA ATL',
#   'leaguePoints': 23,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'bEIsaE1xsYeVEMXohQRczFY4c5XqLT_ACZawafJg9oniOP8',
#   'summonerName': 'IronTownFighter',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 33,
#   'losses': 11,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'EsYqThWopEqm4fs-2vXJusmKSV2oB_FotjX0ZG3LJc_o1OEtJbMkDIIjeg',
#   'summonerName': 'Sajed',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 23,
#   'losses': 19,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '3V9WL7PE6WPG-oa8NSho-gnW3bDvvifd9Qk8wmG9UQobH6pn',
#   'summonerName': 'KENPACHI1',
#   'leaguePoints': 48,
#   'rank': 'I',
#   'wins': 45,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'zHarsbT4jolIYGP66Gp3m_qGMmNuzsmtW9vLTzEFSTCRtRg',
#   'summonerName': 'Sauce XD',
#   'leaguePoints': 18,
#   'rank': 'I',
#   'wins': 43,
#   'losses': 34,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'gIRdcgmbs4xkw6heNLEBf2ElpeZzgkIhKFAMcvkDNogPcis',
#   'summonerName': 'Tentacle Student',
#   'leaguePoints': 74,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'M0xM6nfeWbA7U1vDCkrMBWxSm5ar6eb1_vqwGDE_q33CN4GvMIyqbQT-rg',
#   'summonerName': 'TheSkyfallsforme',
#   'leaguePoints': 203,
#   'rank': 'I',
#   'wins': 102,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Px3BOPt06f7bB6IyocO09MmMkf72-Bf6DbtSn9TmJrgFgLg',
#   'summonerName': 'andyincher',
#   'leaguePoints': 30,
#   'rank': 'I',
#   'wins': 26,
#   'losses': 22,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'O0avKy73BO6DLnqn_IFuAWYWbF5AUnamcheFVdcTznrGoow',
#   'summonerName': 'Twtv TomCat',
#   'leaguePoints': 19,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '7t0kOeNkSHCqF3hODTeNNRO2CW8-sRr_hSMEfd5bHstfPsc',
#   'summonerName': '3uphoria',
#   'leaguePoints': 82,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Pu5g0OufsXwlZ1sXXGfsZsMVlY4dHrfV3DUO-kmV51UX10c',
#   'summonerName': 'Nickji',
#   'leaguePoints': 17,
#   'rank': 'I',
#   'wins': 48,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Pi7LMksNMlREvy__BFu_6oeiiZ8LR-fGPkfwBaG9GGTPt1g',
#   'summonerName': 'Owlbum',
#   'leaguePoints': 23,
#   'rank': 'I',
#   'wins': 50,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'zZvY0L35opNIbUoxi6smiXOoY69qcLjQtOoOUkCKaTDoIYs',
#   'summonerName': 'winner obv',
#   'leaguePoints': 93,
#   'rank': 'I',
#   'wins': 35,
#   'losses': 26,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ZDe_ypGT69jwdtrBhtAZ70CojC4WJstZzajb1XL7oCywYlc',
#   'summonerName': 'needyhenry',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 63,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'QagHHauWTb8BFLfUSEGuCCLS2Bbqt7FeMlqrCfXcEZM8ruarp26kBPuKDw',
#   'summonerName': 'YUHHHHHHHHHHHHH',
#   'leaguePoints': 13,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'ZXPoEbfAv4rGEja3MofCDA0YZfMpEh4Fgmtk1MesKmPvbhSS',
#   'summonerName': 'DSKMTMCHHH',
#   'leaguePoints': 83,
#   'rank': 'I',
#   'wins': 36,
#   'losses': 29,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'RwmXhAKvgsXKDVS8dqAD2H0YTcjdNguttls3InVg4M8wkIcfeiGRefzNXg',
#   'summonerName': 'Mnew',
#   'leaguePoints': 133,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 81,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'ztXTkr5CJWS0BsI0jRqcuo6uRCbWTn51v4WPik-CXec-XeQ',
#   'summonerName': 'Teesum',
#   'leaguePoints': 153,
#   'rank': 'I',
#   'wins': 45,
#   'losses': 39,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'v7NemEIUoWN1hvC1EoRk9SzQZXwviCkfLLmsw5hNbVmoJsc',
#   'summonerName': 'Móíst',
#   'leaguePoints': 55,
#   'rank': 'I',
#   'wins': 39,
#   'losses': 41,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'Ei6jUOnG6hrhSnl8Fqx57u9O-8KLUwCuCzjvaJyaDgGCM2w',
#   'summonerName': 'Eisuke',
#   'leaguePoints': 6,
#   'rank': 'I',
#   'wins': 55,
#   'losses': 58,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'qhAM0iHI6eCqqBTKEesB-iK_-fOH_T0tlI0N4hFmtL54AI0',
#   'summonerName': 'MalevolentTitan',
#   'leaguePoints': 91,
#   'rank': 'I',
#   'wins': 42,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'WBv0YTKtUoGnYekGKrm9i21OeIU_h2B8ltI6USRG4ZEXm_k',
#   'summonerName': 'Master for Mo',
#   'leaguePoints': 4,
#   'rank': 'I',
#   'wins': 29,
#   'losses': 29,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'iaMiE2NJVUcLZPcdsJYuqQP8JJDuxYMZROy7XDoWkE_u_3Y',
#   'summonerName': 'CupGin',
#   'leaguePoints': 54,
#   'rank': 'I',
#   'wins': 52,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'dbCyli5cgRdzYb1ahhzUSINuUa5TFcbfLAS1ENo8Q7IPScA',
#   'summonerName': 'Angelomaniac',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 76,
#   'losses': 62,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '46j5BKMFLXVRa1sbAEzEJHpm0D-JVEdjK_3CAa5Ey61k4sdQKLCqRjVNjg',
#   'summonerName': 'duo bigfat',
#   'leaguePoints': 153,
#   'rank': 'I',
#   'wins': 69,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'nkVfLtxGAFd6SCPsqz82d1Vf-DGsCppvhDh5iwYsG26t4QM',
#   'summonerName': 'TheGreatHazam',
#   'leaguePoints': 4,
#   'rank': 'I',
#   'wins': 46,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'CUkvY78iCYlNw5J8ZNCxxJmwgBgjXVSeCrAeV3UtyQfHe1Q',
#   'summonerName': 'Big D Hashira  ',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 27,
#   'losses': 25,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'NG9CDy-Gy3aGYZRGGmCAFSqJ6YE7cxcUxHs5b0Khyp7ntH7W',
#   'summonerName': 'xiang ni kai xin',
#   'leaguePoints': 38,
#   'rank': 'I',
#   'wins': 32,
#   'losses': 27,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'lwaVT_AL4l2nIjYaR3TW1Q7tFcZbeI8EJLk5QXPzSLljuU8',
#   'summonerName': 'ff15 we lost',
#   'leaguePoints': 38,
#   'rank': 'I',
#   'wins': 43,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'OvUXJ1eeP4dRHFresitTaqID0r8qtSVKDtyCEf5IqcBq-F5b',
#   'summonerName': 'YørdleQuęęn',
#   'leaguePoints': 148,
#   'rank': 'I',
#   'wins': 57,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'UgsLTN9119QVEOiMkNLUPN0n1F01MMLmCmIAf-VvRjfSLLEL',
#   'summonerName': 'ButtBoon',
#   'leaguePoints': 13,
#   'rank': 'I',
#   'wins': 53,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'kCU2Ps4YC6rRA9cdJwtCs0X8mnm6mzrArwedd4zmCZPzV6w',
#   'summonerName': 'brownpeanuts',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 39,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'CiGhiVrlj9OgShK00L5sd4GFd4gfvYD8e5PBkLIUNA7S4FY',
#   'summonerName': 'Uzi of NA',
#   'leaguePoints': 21,
#   'rank': 'I',
#   'wins': 46,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'kINY3qzFw55u8Ex_yHb4ctXWL7aWu6VkmkDl_JEdSv02wsMakxDtCIYA7g',
#   'summonerName': 'DC EGC Zhuimeng',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 39,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'FKiiR0Ev_CFBkVxWz-vDuG0rIjBJq5FFItMpOD6ZuvDoJ3c',
#   'summonerName': 'Daddy Jame',
#   'leaguePoints': 19,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'xZvXIChd8fj_CP5yeYvQeREEqUskOXPRWTlL-CNy1RWe2Ig',
#   'summonerName': 'Kriffi',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 31,
#   'losses': 36,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'r7lk1-JFI7rnO7QpXw-wckuTAwTQrg_Y5CaSsX9NbJspZgo',
#   'summonerName': 'Max JG',
#   'leaguePoints': 196,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'T5HbQWzkDNrYhCo6uDddv2jmdfHalxLqblAdvHwYZmTgq1g',
#   'summonerName': 'ShiShenHaiYuMa',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 52,
#   'losses': 13,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'MjGMSvZ2q1rlqozwsONRsetYrc2fUo5RpMCDn1i1PtphKNs',
#   'summonerName': 'fránco',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 54,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'aeES9iOqB1BCcTEoXkCp1KW9DgepRUgMBCjkB0GvoyFPsCbfztAsV2Cnfg',
#   'summonerName': '16 Days Left',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 21,
#   'losses': 9,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'wwrsVphqO8CH5E57YbtJDtM56VC-8uq1ysfNNh9NoGrpjmQC',
#   'summonerName': 'fClXmCeleste',
#   'leaguePoints': 146,
#   'rank': 'I',
#   'wins': 43,
#   'losses': 40,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '1aemG4P17m7zqZ5nOvITtOslR_qsAMYrq8yNdzLX2bSIDms',
#   'summonerName': 'KiteAzure',
#   'leaguePoints': 21,
#   'rank': 'I',
#   'wins': 39,
#   'losses': 35,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'FQU_ra-o8A0WwE0X0njCtGwhAH1_3KdQrYttpHth3kXBfPw',
#   'summonerName': 'Hero Galaxy',
#   'leaguePoints': 93,
#   'rank': 'I',
#   'wins': 136,
#   'losses': 107,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'c9goGaclOy5_PeQKfu5sEkih0k8VS-99_hytje9jk-Hod_Q',
#   'summonerName': 'fox solo',
#   'leaguePoints': 48,
#   'rank': 'I',
#   'wins': 40,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'uNHDnaqwbVW4iOHCkFq7polUYve9DG_pQ3SEGmXHypDIEyw',
#   'summonerName': 'hxppythoughts',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'LkK7PMFq0WUFRe0GS5a9B8USk5loR8pGoNFQIfNFIoAbvH8',
#   'summonerName': 'MëowMix',
#   'leaguePoints': 94,
#   'rank': 'I',
#   'wins': 40,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'OMDwoMuSZfR5sj6vs8H-5k80wv2mxH6gQ4n8IFHfcBC3Dbs',
#   'summonerName': 'ItzAraGuys',
#   'leaguePoints': 149,
#   'rank': 'I',
#   'wins': 30,
#   'losses': 20,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'IPWiV7vupCR6TORZdj0I0c0PUWYhBiIFWPDfYKBeLasbXz0',
#   'summonerName': 'Convere',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 36,
#   'losses': 31,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'laxePmpBiry0X6LdmedpktPYc2DhKEgpkrR40PvIRuXpLlk',
#   'summonerName': 'im risk',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 40,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '4abMg_W8yoV9Gwe-f-YoZKvNCyrdMOB7W7UEtlC9w5oORCQb',
#   'summonerName': 'Aleria',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 36,
#   'losses': 25,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'OqSWGeQT9ZaH2nSlkIhMy0XPOL_4Pv1IJbec2O7qrT0K3QM',
#   'summonerName': 'OrgasmicP',
#   'leaguePoints': 103,
#   'rank': 'I',
#   'wins': 109,
#   'losses': 112,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'scYN8j1IG4o79o_p7Zncxh4X6F7LEqP4hzczoo5nZkChHu8',
#   'summonerName': '1743',
#   'leaguePoints': 44,
#   'rank': 'I',
#   'wins': 25,
#   'losses': 18,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'M8KwDZ50yuvCx_-2h4-2Udz-1bLa1mSEVxEJXt1Q3ClhQpY',
#   'summonerName': 'Barry Buggles',
#   'leaguePoints': 26,
#   'rank': 'I',
#   'wins': 21,
#   'losses': 14,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'r9m3Wd9OKrQO8S5BhevJM286upTL42f9R1B2X99SiJSdscw',
#   'summonerName': 'XXXLEO',
#   'leaguePoints': 66,
#   'rank': 'I',
#   'wins': 24,
#   'losses': 15,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'c3i5G3dS1OTkSUMLCzRDtW9R9BxkiD839tpklHKx-uQjNZ0',
#   'summonerName': 'scott joseph',
#   'leaguePoints': 36,
#   'rank': 'I',
#   'wins': 49,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'gxP0L69_hAyOvBYhCMGAqDyIH7qXhwuV19kbznzttoPtpTU',
#   'summonerName': 'Le Gom',
#   'leaguePoints': 101,
#   'rank': 'I',
#   'wins': 88,
#   'losses': 83,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'gAE8CKuxdLJ1jI-nq8LiVxAQ8i461O5FmZ8WRCCam2e6PLY',
#   'summonerName': 'sgrug4',
#   'leaguePoints': 23,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'mhcPaxLwUCbEGETIatj_2z_65DZGTmnOv50GKEivoRn1Ipw2VXM0urO7yg',
#   'summonerName': 'QuillVIII',
#   'leaguePoints': 39,
#   'rank': 'I',
#   'wins': 33,
#   'losses': 30,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': '33LAVSBSppUR7lCJ36e41ZgXRJ6mspSmIdOEJi8lzQvYkL0',
#   'summonerName': 'Lossiferr',
#   'leaguePoints': 42,
#   'rank': 'I',
#   'wins': 50,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'ZM0qGrtuRQm0pss7aRHdnA-X24JpsjBMfOkv28kMKdyDp_M',
#   'summonerName': 'UnIess',
#   'leaguePoints': 125,
#   'rank': 'I',
#   'wins': 39,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'BlSDPNnG5dx0jc0FEP4gUqdvftaeN9UMWfm8aov-OlNOTW4',
#   'summonerName': 'IKony',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'tAGlPTORMwOdLyypT9J_A9jd8vw2Mhk8nlG1ixXylmfDrQ7H',
#   'summonerName': 'TwitchTv Sheiden',
#   'leaguePoints': 164,
#   'rank': 'I',
#   'wins': 41,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'g26Gdj6j7f8VOl700OWUQrToYX5hR8z_drRBUPoN0o9RZZE',
#   'summonerName': 'Zu An Nan Hai',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 121,
#   'losses': 98,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'oMxjhbvT_CyXnTOr7vgM7LGYXtE2xSGrTt_jQAmvib3H8Dfel5OwdS_aMg',
#   'summonerName': 'llIIlIlIlIllll',
#   'leaguePoints': 53,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'fUlqBYq2g11vgDxWc375kDqGVuOG2oSoQ44yLaLRd6VLpr0',
#   'summonerName': 'Boster',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 48,
#   'losses': 41,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'F18U1RBj2AElNIXyKpwc653JP94NUeW8xF__WAsM6Q9xO6hCfFr1FPw5cg',
#   'summonerName': 'A Lvl 6 Poro',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 60,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '1n0z0rimZ67ZyShCXlvCukFgsTV01q81rxUPMz-NxDCvexs',
#   'summonerName': 'The Crazy Goose',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 88,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '-xaSegZXnnalMfDvi8uRHEnTzPns5l78WIvkuY3DMfWVwkg',
#   'summonerName': 'Shibas',
#   'leaguePoints': 49,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '5v07YZZaX87Ku8YgHLrG29jsn1au4dmbDamOJc9czYAwHPU',
#   'summonerName': 'MEECHOL MANIA',
#   'leaguePoints': 81,
#   'rank': 'I',
#   'wins': 38,
#   'losses': 35,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'iC73IluBucoXFwM1tFW9DggPpHbvEw-VY3r0wIk8alZMrv8',
#   'summonerName': 'Dueygolf',
#   'leaguePoints': 47,
#   'rank': 'I',
#   'wins': 40,
#   'losses': 34,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'TJvMucv5lQbPCpoxtfKa7pJXlXH17-qC7SehL9fCD7m1IUeH9RPOjEwBgA',
#   'summonerName': 'aespaWinterrrr',
#   'leaguePoints': 123,
#   'rank': 'I',
#   'wins': 56,
#   'losses': 56,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'PtYUbCwMArV4amw3nqkP33qFpe4yczXNEUye-ZAM-EH6gk4',
#   'summonerName': 'Mside Profit',
#   'leaguePoints': 34,
#   'rank': 'I',
#   'wins': 50,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'rTKYKb2JmKIKmeSLQMtHQcN8pf8nCLkDyNPLgv87ii0sBxpf',
#   'summonerName': ' ßren267',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 105,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'Y4bgVoehxlY06qC9NaS1fIR6kXJon4zRitifCKWNYe049hA',
#   'summonerName': 'lemontartdreamer',
#   'leaguePoints': 105,
#   'rank': 'I',
#   'wins': 92,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'YWRPcYKSuluARaV69j41k4CG6xL7PO3rWvO7noz70DqCT_s',
#   'summonerName': 'Bluwunk',
#   'leaguePoints': 91,
#   'rank': 'I',
#   'wins': 53,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'WI-gtWr-_YCfusip7fowThmgcB-Qc-OrE_o6kEHj9DuJQPg',
#   'summonerName': 'MushroomSteak',
#   'leaguePoints': 82,
#   'rank': 'I',
#   'wins': 27,
#   'losses': 21,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': '97XNY7PEr-9ap-vwyecAaxVJ5xCNgo0dSzCSNtKBBwr8jIQ',
# ...
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'wlLqg253a2oTDGNOwdZ_egOS5HjEbeddjN1LdgfIWBMjdRJA',
#   'summonerName': 'MXT',
#   'leaguePoints': 19,
#   'rank': 'I',
#   'wins': 37,
#   'losses': 30,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'GcI39xkppJ-HUyDVRYAUvmTByXPxgQqZGkaSiklX8T9ifsU',
#   'summonerName': 'UCI duong pro',
#   'leaguePoints': 20,
#   'rank': 'I',
#   'wins': 26,
#   'losses': 23,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '2BHTxCjmylxb77fvkwgs4r7CfyqbxogVUieo6cUh5NrKX0Q',
#   'summonerName': 'Bombzilla',
#   'leaguePoints': 128,
#   'rank': 'I',
#   'wins': 32,
#   'losses': 16,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': 'M0shgx1NYAMKyNDj1ZWxWbatczyJxt7G7LjwDz5p21iL3FI',
#   'summonerName': 'chicks oh lay',
#   'leaguePoints': 86,
#   'rank': 'I',
#   'wins': 51,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'wtVtwObpvecRcrARIMhlvzkICNnV3CqWThfyTaSVbKrxqoU',
#   'summonerName': 'May it be',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 35,
#   'losses': 31,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'YG4n1bWx8M5iQeGxj3OBzwK3GwS5vQrL47dqf41vaKCVTwI',
#   'summonerName': 'Teacuppers',
#   'leaguePoints': 42,
#   'rank': 'I',
#   'wins': 19,
#   'losses': 10,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'wqErJQofy7XYwkFJmi90seQZzoF35GBGUHcHVwEGXx3-xsA',
#   'summonerName': 'Kyriu',
#   'leaguePoints': 49,
#   'rank': 'I',
#   'wins': 21,
#   'losses': 12,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'qLjTkflF_OFxw9QdMCyVfFQX6pMU_TZTb7yrF2sk_8bE7zw',
#   'summonerName': 'deathwalker222',
#   'leaguePoints': 70,
#   'rank': 'I',
#   'wins': 72,
#   'losses': 72,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'GoPHm7hB3Qoe3Jjs75oeFZ4ACckNET-KPTa2E03GyRYre40',
#   'summonerName': 'Enthusiastic Nut',
#   'leaguePoints': 45,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 79,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'iEEMaACnfaM8cKr8nsXR5celxvogo0IFLKvzTOaNeDRytBfk',
#   'summonerName': 'NA The Bug',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 93,
#   'losses': 79,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'o_JrShGECQQ45F_JBVJhAVN47S_06K2nUVrNEvGkvox8AVM',
#   'summonerName': 'Zoou',
#   'leaguePoints': 29,
#   'rank': 'I',
#   'wins': 34,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'KTCWsSeiEiynR5idBRBszdGgI3Dv1mN_zhEnuYNPAkFqTqc',
#   'summonerName': 'MySwordCrimson',
#   'leaguePoints': 169,
#   'rank': 'I',
#   'wins': 41,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'D5Koq4jed_YkgmyYlDL7DH69Cb3UYT0oxwN7hdJl2nA1_Dw',
#   'summonerName': 'Jido',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 28,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '7fphy21Z64lakK1SsQri6iwH5CExr4GahAkZuDL0XmqFrGA',
#   'summonerName': 'ANTHONY EVELYNN',
#   'leaguePoints': 33,
#   'rank': 'I',
#   'wins': 28,
#   'losses': 24,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'cj9GThM5rCz8dMEv3cEr-PFF5YUk5nVQhDHg_pC7JrS_wz0',
#   'summonerName': 'IToldYouImCar',
#   'leaguePoints': 33,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'l-2-wQFPOy0HVQlhbYABWtavZgKcFCbr4MkbG4ELudUPfL0T',
#   'summonerName': '    Tong Tong ya',
#   'leaguePoints': 155,
#   'rank': 'I',
#   'wins': 48,
#   'losses': 48,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'MuIs-4A5EUCYqgGz8sgGHRFaZwhU5qKH9lKLXOMN_-KiFBM',
#   'summonerName': 'The Golden King',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 24,
#   'losses': 19,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'KrIfilh0xPofww5v5B2TKi31paZ_-DXqun51jeC0ri990gc',
#   'summonerName': 'DDOSS',
#   'leaguePoints': 136,
#   'rank': 'I',
#   'wins': 62,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'TJS3D3ZDz1ANn90tl9FmZB84_TIpH-TPl42hiZksa0KzwkwuY2Kjg4GV4Q',
#   'summonerName': 'SirErpez',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 22,
#   'losses': 19,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'sV25ZAGnVqG6IHX-WuKIQUWnVhcT7YQewHPR2m6fNbyvn9Y',
#   'summonerName': 'Jraff',
#   'leaguePoints': 149,
#   'rank': 'I',
#   'wins': 32,
#   'losses': 20,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '4FSO4446h_FOiniJjq9LKBOiDo2uMCueYWzMtfUk3HePuQ2k8vm2dRcxTg',
#   'summonerName': 'Raheen',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 37,
#   'losses': 16,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'yzI6DYbikTAdUcK7vWWWYPMNPRb9li42EsZF-Y-1vfrsyCc',
#   'summonerName': 'XiâoMíng',
#   'leaguePoints': 110,
#   'rank': 'I',
#   'wins': 33,
#   'losses': 22,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'vdnvC0Y1myHmZRvvEruKRnmUGSiC4JQGoDQjNkJwgjboq5A',
#   'summonerName': 'Go camille Go',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 29,
#   'losses': 25,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '59jcHpDtUFGdT5IemataKyOweb39gOMDtf5mJx3Ad_40hVk',
#   'summonerName': 'jg 1v9',
#   'leaguePoints': 120,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 57,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'UulhN87V40LC_DUS7mbERygeZDVtB9S82pOsYggtXEHdzI8',
#   'summonerName': 'nosad',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 28,
#   'losses': 15,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'QM2GoIAyHqE-x49hDtav_IWPn2zcUyovKDTAv7J3Zt7M2FNF',
#   'summonerName': 'KKYY',
#   'leaguePoints': 19,
#   'rank': 'I',
#   'wins': 35,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'yy21l0GZbAatuV1030F6-8Ivex_BdXuErJ-eYjbo1emirzY',
#   'summonerName': 'ImpulseIV',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 99,
#   'losses': 113,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'g7VGLUXJfCZOhDMPGCaznq6TtVoIUp_lqLUXQWuNt_Hsu_I',
#   'summonerName': 'SHM Apu',
#   'leaguePoints': 184,
#   'rank': 'I',
#   'wins': 77,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'IJOClM4rCIXd2g6925XOUj5BFqpiNMmIb0waP15qB6j8vDc',
#   'summonerName': 'Grilotrix',
#   'leaguePoints': 72,
#   'rank': 'I',
#   'wins': 46,
#   'losses': 31,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_JRmfIX6arMZ8hXgsw98cx0kNh0Xxhmad1uKrRCaFmGRSLc',
#   'summonerName': 'GENTLEMENINPARIS',
#   'leaguePoints': 94,
#   'rank': 'I',
#   'wins': 119,
#   'losses': 113,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '9CvJOHStTg1lu3-XTLDY0tvfW4sWLpisWeQ3fXgZStPtHI0',
#   'summonerName': 'A x J',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'uk2s_5yw3bc8sq4K_mCCWM3B2Gdsx8wEJ6NKu8n6N14vmeM',
#   'summonerName': 'Mamitas Puebla',
#   'leaguePoints': 12,
#   'rank': 'I',
#   'wins': 32,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'U9hFff9MN7pd1oojNwc1Wa_D6Vm7TUEn-4ceEu5RALGaDXy0qOSEg5DNnw',
#   'summonerName': 'king dior',
#   'leaguePoints': 24,
#   'rank': 'I',
#   'wins': 71,
#   'losses': 73,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 't-ezXdBalmMjKlg6HVIzPALCAV1NN3vrFHkoCfwicgbzKIU',
#   'summonerName': 'alpha chad fizz',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 94,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '3UCw8eeAFHpBxOVGFJw6XiHTCN6VTd5ite0AsC1M2AgLmi8',
#   'summonerName': 'Sunbob',
#   'leaguePoints': 22,
#   'rank': 'I',
#   'wins': 39,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Kn1Fey_rezY85q-en_-PCOzD0FvfiT7-HbEewRYchpJObRU',
#   'summonerName': 'Meowri Isolated',
#   'leaguePoints': 96,
#   'rank': 'I',
#   'wins': 35,
#   'losses': 20,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'g9Tw0LkAvmk7xVXLD9SqoLi9oWrcokyFBqDYWi53TiW33CE',
#   'summonerName': 'Boosinger',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 66,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'sCGtXnJtTsUXoihIt1kBhPoyTFCsHvXtXjnZcMcw_hps7ADk',
#   'summonerName': 'top gap',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 43,
#   'losses': 36,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Xypc7EKvFdqoSD1baVu21zX7OpRhv9OV6b3xdGtWqT8XVvc',
#   'summonerName': 'Yann51300',
#   'leaguePoints': 76,
#   'rank': 'I',
#   'wins': 52,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'p73uQIWKQ_ebzyZlDOdcxPmmfAmvPMgGm2gzVg4U6Uqxch4',
#   'summonerName': 'nopointanymore',
#   'leaguePoints': 116,
#   'rank': 'I',
#   'wins': 77,
#   'losses': 58,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'P-HT7zQk2copeQoZVq0CWksTVkwTwLRkh6sgq5z215oUsdI',
#   'summonerName': 'xVanyZ',
#   'leaguePoints': 0,
#   'rank': 'I',
#   'wins': 101,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'nfWzE2wM_rnqPW7uAo9UkipoE99-8MjCHsgC5fgG47mtIFqEdcp0xpm_FA',
#   'summonerName': 'KissyAdc1',
#   'leaguePoints': 13,
#   'rank': 'I',
#   'wins': 78,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'g56rtn3pkMYPWBo4C_ysggzbl2a6UxUm_V26lxvixDzyfeA',
#   'summonerName': 'Jade Is Cute',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'AgUsWswyl3-U1C-HSjKGmByoTjpsxRq-xeq0wReQRy7a1eU',
#   'summonerName': 'H4xDefender',
#   'leaguePoints': 76,
#   'rank': 'I',
#   'wins': 24,
#   'losses': 16,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'summonerId': 'u8h5VBpByrd53JOFsqeXICboCM3qbWqlLfbgdAVqGcbJL4PR',
#   'summonerName': 'Pepoggers',
#   'leaguePoints': 25,
#   'rank': 'I',
#   'wins': 59,
#   'losses': 44,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'V-1IgZ3kd_CGnz-rh_7yVKtVOUc0lBhtZTSLqQX6yDk1Fuc',
#   'summonerName': 'Zethal',
#   'leaguePoints': 46,
#   'rank': 'I',
#   'wins': 20,
#   'losses': 20,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '_UX2Hw5l43L4Bc-gzCjm0pnck4EYDW7IdiSFfil6SVSrSwM',
#   'summonerName': 'FedoraTipper',
#   'leaguePoints': 32,
#   'rank': 'I',
#   'wins': 96,
#   'losses': 81,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'MSFI6xScZG2TcG2s_ImiPXqcu52UZqlY1noW3d9Kt8IWN2s',
#   'summonerName': 'lIllIIIllIlIlI',
#   'leaguePoints': 11,
#   'rank': 'I',
#   'wins': 36,
#   'losses': 35,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'SW9H3MMgNcntiiq5tMIliy20lK4C8Tm8RHNz9gLQyGGAq1k',
#   'summonerName': 'Sexual Healîng',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 57,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '0jjs5qzUBECbpyAEeb8NuDu7OU7868nHTPY_mqWWYiIO1Zw',
#   'summonerName': 'Teemo is weak',
#   'leaguePoints': 107,
#   'rank': 'I',
#   'wins': 36,
#   'losses': 36,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'Ts8o9eeMYEythZlwMBwQ1pOjd_u4OlN3nwZcUmidbJZyH7I',
#   'summonerName': 'Bruder',
#   'leaguePoints': 106,
#   'rank': 'I',
#   'wins': 50,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'D2-0qKUa2gfQw68Y42xUFsVxijGKG9T7t2RHv8Du3jpuuRM',
#   'summonerName': 'Dunksquad101',
#   'leaguePoints': 168,
#   'rank': 'I',
#   'wins': 40,
#   'losses': 30,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'summonerId': '8RJDt99AxzBhyjQcDXXWOYKoMR718UR7IFN2ksj7qKXJSiM',
#   'summonerName': 'NODREAM',
#   'leaguePoints': 168,
#   'rank': 'I',
#   'wins': 32,
#   'losses': 23,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '6AE40-THg_0vHl_OTzGo4MvYtAic8PZQ8CDYuBVDOr2bUcp4Pxo7wpSZkg',
#   'summonerName': 'RedSorbet',
#   'leaguePoints': 193,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': '1TYBhNRuDhwQafibXQZVNsZpoT24IhI8ERBqYvQL_RpCQ6o',
#   'summonerName': 'Dadumdum',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 93,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'UsppJg5H49hKD83HOBZ4OQ6ggAreaw9a6pepJo6vUlEUhTI',
#   'summonerName': 'Nariman',
#   'leaguePoints': 11,
#   'rank': 'I',
#   'wins': 60,
#   'losses': 52,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'KJvKPHDFqL0LH6FtH-WDkcl7TMiv1vbSX2HbLQNB1SGQ5GI',
#   'summonerName': 'Resh',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 28,
#   'losses': 26,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'id4ZfDODxZIbOhGxDfptGOzT6ThuxUl270nWx7kwgOXNK6M',
#   'summonerName': 'Outplay',
#   'leaguePoints': 56,
#   'rank': 'I',
#   'wins': 26,
#   'losses': 21,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'hBMSvRw-j_GwIcHPjrZP5iygSbVZg7bZGyQDNJbc34WJijQ',
#   'summonerName': 'Basik',
#   'leaguePoints': 44,
#   'rank': 'I',
#   'wins': 48,
#   'losses': 38,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'p-59F0Z9B3fSRADl89tL0t0YWnQ0IGWQw1giQMokC9kqBFI',
#   'summonerName': 'FocusTIME',
#   'leaguePoints': 19,
#   'rank': 'I',
#   'wins': 41,
#   'losses': 32,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'qQk98MxeO_73BJSU07-4Qm7tln96WcDtbSX3OhoeMxRfCfIu',
#   'summonerName': 'a1cu',
#   'leaguePoints': 1,
#   'rank': 'I',
#   'wins': 41,
#   'losses': 28,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'summonerId': 'DI_7AsZI21YxOb5EghUDieYLcBmaOv9FFMruza0oC55-Of0seW-tc3mLyA',
#   'summonerName': 'Tencent is gay',
#   'leaguePoints': 141,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'summonerId': 'HZhYZ7rkecawn3kLEVYlUPq4Jdef1fGTpTn59xbG_6Kh8vI65kolFuVSfQ',
#   'summonerName': 'Jomed',
#   'leaguePoints': 17,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  ...]

# %%
high_elo_players = []
for summoner in challenger_players:
    high_elo_players.append(summoner["summonerName"])
    
for summoner in grandmaster_players:
    high_elo_players.append(summoner["summonerName"])
    
for summoner in master_players:
    high_elo_players.append(summoner["summonerName"])

print("Length: ", len(high_elo_players))
high_elo_players[0:5]
# Out:
# Length:  1873
# ['Ćocá', 'meiyouhuitoulu', 'TL Jensen', 'Detention', 'Yura1']

# %%
def get_summoner_uid(name):
    try:
        summoner = watcher.summoner.by_name(region, name)
    except ApiError:
        return "No summoner found"
    return summoner["puuid"]

# %%
def get_data_from_match(player_uid):
    
    match_list = watcher.match.matchlist_by_puuid('americas', player_uid, type="ranked")
    
    for match in match_list:
        game_timeline = watcher.match.timeline_by_match('americas', match)
        game_details = watcher.match.by_id('americas', match)
        if game_details["info"]["participants"][0]["win"] == True:
            winner = "Team 1"
        else:
            winner = "Team 2"
                
       
        if len(game_timeline['info']['frames']) < 22:
            # print("less than 20")
            continue 
        # print("more than 20")
        frames =  game_timeline['info']['frames'][:22]
        
        # get gold diff 
        gold = {}
        for k in range(len(frames)):
            gold['{}'.format(k)] = {}
        for value in gold.values():
            for l in range(1, 11):
                value['{}'.format(l)] = 0

        for m in range(len(frames)):
            for n in range(1, 11):
                gold['{}'.format(m)]['{}'.format(n)] = game_timeline['info']['frames'][m]['participantFrames']['{}'.format(n)]['totalGold']

        blue_gold = []
        red_gold = []
        
        for key in gold.keys():
            team1 = 0
            team2 = 0
            for o in range(1, 6):
                team1 += gold[key]['{}'.format(o)]
                team2 += gold[key]['{}'.format(o + 5)]
            blue_gold.append(team1)
            red_gold.append(team2)

        # gold_diff = (np.array(team_1_gold) - np.array(team_2_gold)).tolist()
        
        
        blue_dragons = 0
        blue_heralds = 0
        red_dragons = 0
        red_heralds = 0
        blue_barons = 0
        red_barons = 0

        for frame in frames:
            for event in frame["events"]:
                if "monsterType" in event.keys():
                    if event["monsterType"] == "DRAGON":
                        if event["killerTeamId"] == 100:
                            blue_dragons += 1
                        else:
                            red_dragons += 1
                    if event["monsterType"] == "RIFTHERALD":
                        if event["killerTeamId"] == 100:
                            blue_heralds += 1
                        else:
                            red_heralds += 1
                    if event["monsterType"] == "BARON_NASHOR":
                        if event["killerTeamId"] == 100:
                            blue_barons += 1
                        else:
                            red_barons += 1
          
        # print(match, blue_gold[-1], red_gold[-1], blue_dragons, blue_heralds, blue_barons, red_dragons, red_heralds, red_barons)
        
        blue_k = 0 # blue side (bottom)
        red_k = 0 # red side (top)

        for frame in frames:
            for event in frame["events"]:
                if "victimId" in event.keys():
                    if event["type"] == "CHAMPION_KILL":
                        if event["killerId"] == 0:
                            continue
                        if 1 <= event["killerId"] <= 5:
                            blue_k += 1
                        else:
                            red_k += 1
                            
        blue_obj = 0
        red_obj = 0
        for frame in frames:
            for event in frame["events"]:
                if "buildingType" in event.keys():
                    if event["teamId"] == 100:
                        red_obj += 1
                    else:
                        blue_obj += 1
        
        # print(match, blue_dragons, blue_heralds, blue_barons, blue_obj, blue_k, blue_gold[-1], red_dragons, red_heralds, red_barons, red_obj, red_k, red_gold[-1], winner)
        cur.execute(insert_match, (match, blue_dragons, blue_heralds, blue_barons, blue_obj, blue_k, blue_gold[-1], red_dragons, red_heralds, red_barons, red_obj, red_k, red_gold[-1], winner))
        connection.commit()
        sleep(0.84)

# %%
for name in high_elo_players:
    player_uid = get_summoner_uid(name)
    if player_uid == "No summoner":
        continue
    try:
        get_data_from_match(player_uid)
    except:
        continue

# %%
print("finished gathering data")
